# %% [markdown]
# ### 코로나 데이터 웹 데이터 수집

# %% [markdown]
# ### 학습내용
# * 추가적인 내용을 수집한다.(인구수, 위중증 추가)
# * 금일 정보가 아닌 어제기준 완료된 데이터를 가져와 본다.

# %% [markdown]
# * 코로나 19(COVID-19) 실시간 상황판
# * url : https://coronaboard.kr/

# %%
from IPython.display import display, Image
import os, warnings
import re
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ### 01 웹 브라우저 띄우기

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

# %%
driver = webdriver.Chrome('./chromedriver_91')

## https://www.amazon.com/
url = 'https://coronaboard.kr/'
driver.get(url)

import time
time.sleep(3)  # 홈페이지 로딩 시간 3초

# %% [markdown]
# ### 02 더보기 버튼 찾기

# %%
from selenium.webdriver import ActionChains

some_tag = driver.find_element_by_id('show-more')
ActionChains(driver).move_to_element(some_tag).perform()
some_tag.click()

# %%
some_tag = driver.find_element_by_id('show-more')
ActionChains(driver).move_to_element(some_tag).perform()
some_tag.click()

# %% [markdown]
# ### 03 추가정보선택
#  * 콤보박스 : //*[@id="global-slide"]/div/div[2]/div/div/button/div/div/div

# %%
combo_xpath = '//*[@id="global-slide"]/div/div[2]/div/div/button/div/div/div'
some_tag = driver.find_element_by_xpath(combo_xpath)
ActionChains(driver).move_to_element(some_tag).perform()
some_tag.click()

# %% [markdown]
# * //*[@id="bs-select-1-5"]

# %% [markdown]
# ### 치료중 추가

# %%
sel_menu = driver.find_element_by_xpath('//*[@id="bs-select-1-0"]')
sel_menu.click()

# %% [markdown]
# ### 인구수 추가

# %%
sel_menu = driver.find_element_by_xpath('//*[@id="bs-select-1-5"]')
sel_menu.click()

# %% [markdown]
# ### 위중증 추가

# %%
sel_menu = driver.find_element_by_xpath('//*[@id="bs-select-1-1"]')
sel_menu.click()

# %%
some_tag.click()

# %% [markdown]
# ### 국가 정보 가져오기

# %% [markdown]
# * //*[@id="country-table"]/div/div/table/tbody/tr[1]/td[2]/a
# * //*[@id="country-table"]/div/div/table/tbody/tr[2]/td[2]/a
# * //*[@id="country-table"]/div/div/table/tbody/tr[4]/td[2]/a

# %%
country_xpath = '//*[@id="country-table"]/div/div/table/tbody/tr/td[2]'
sel_country = driver.find_elements_by_xpath(country_xpath)
len(sel_country)
# Out:
# 223

# %%
for one in sel_country:
    print(one.text)
# Out:
# 미국🇺🇸
# 인도🇮🇳
# 브라질🇧🇷
# 영국🇬🇧
# 러시아🇷🇺
# 터키🇹🇷
# 프랑스🇫🇷
# 이란🇮🇷
# 독일🇩🇪
# 아르헨티나🇦🇷
# 스페인🇪🇸
# 콜롬비아🇨🇴
# 이탈리아🇮🇹
# 인도네시아🇮🇩
# 멕시코🇲🇽
# 폴란드🇵🇱
# 우크라이나🇺🇦
# 남아프리카 공화국🇿🇦
# 필리핀🇵🇭
# 말레이시아🇲🇾
# 네덜란드🇳🇱
# 페루🇵🇪
# 체코🇨🇿
# 태국🇹🇭
# 이라크🇮🇶
# 캐나다🇨🇦
# 루마니아🇷🇴
# 칠레🇨🇱
# 일본🇯🇵*
# 벨기에🇧🇪
# 방글라데시🇧🇩
# 이스라엘🇮🇱
# 파키스탄🇵🇰
# 세르비아🇷🇸
# 베트남🇻🇳
# 스웨덴🇸🇪
# 오스트리아🇦🇹
# 포르투갈🇵🇹
# 헝가리🇭🇺
# 스위스🇨🇭
# 카자흐스탄🇰🇿
# 쿠바🇨🇺
# 모로코🇲🇦
# 요르단🇯🇴
# 그리스🇬🇷
# 조지아🇬🇪
# 네팔🇳🇵
# 아랍에미레이트🇦🇪
# 튀니지🇹🇳
# 불가리아🇧🇬
# 슬로바키아🇸🇰
# 레바논🇱🇧
# 벨라루스🇧🇾
# 과테말라🇬🇹
# 크로아티아🇭🇷
# 아제르바이잔🇦🇿
# 코스타리카🇨🇷
# 스리랑카🇱🇰
# 아일랜드🇮🇪
# 사우디아라비아🇸🇦
# 볼리비아🇧🇴
# 에콰도르🇪🇨
# 미얀마🇲🇲
# 덴마크🇩🇰
# 파나마🇵🇦
# 리투아니아🇱🇹
# 파라과이🇵🇾
# 대한민국🇰🇷
# 베네수엘라🇻🇪
# 팔레스타인🇵🇸
# 슬로베니아🇸🇮
# 쿠웨이트🇰🇼
# 도미니카 공화국🇩🇴
# 우루과이🇺🇾
# 몽골🇲🇳
# 온두라스🇭🇳
# 리비아🇱🇾
# 에티오피아🇪🇹
# 몰도바🇲🇩
# 이집트🇪🇬
# 아르메니아🇦🇲
# 오만🇴🇲
# 바레인🇧🇭
# 보스니아 헤르체고비나🇧🇦
# 싱가포르🇸🇬
# 노르웨이🇳🇴
# 케냐🇰🇪
# 라트비아🇱🇻
# 카타르🇶🇦
# 에스토니아🇪🇪
# 북마케도니아🇲🇰
# 나이지리아🇳🇬
# 잠비아🇿🇲
# 알제리🇩🇿
# 호주🇦🇺
# 알바니아🇦🇱
# 보츠와나🇧🇼
# 우즈베키스탄🇺🇿
# 키르기스스탄🇰🇬
# 핀란드🇫🇮
# 아프가니스탄🇦🇫
# 몬테네그로🇲🇪
# 모잠비크🇲🇿
# 짐바브웨🇿🇼
# 키프로스🇨🇾
# 가나🇬🇭
# 나미비아🇳🇦
# 우간다🇺🇬
# 캄보디아🇰🇭
# 엘살바도르🇸🇻
# 코소보🇽🇰
# 카메룬🇨🇲
# 르완다🇷🇼
# 중국🇨🇳
# 몰디브🇲🇻
# 자메이카🇯🇲
# 룩셈부르크🇱🇺
# 세네갈🇸🇳
# 라오스🇱🇦
# 트리니다드 토바고🇹🇹
# 앙골라🇦🇴
# 말라위🇲🇼
# 코트디부아르🇨🇮
# 레위니옹🇷🇪
# 콩고민주공화국🇨🇩
# 과들루프🇬🇵
# 피지🇫🇯
# 수리남🇸🇷
# 시리아🇸🇾
# 에스와티니🇸🇿
# 프랑스령 기아나🇬🇫
# 프랑스령 폴리네시아🇵🇫
# 마르티니크🇲🇶
# 마다가스카르🇲🇬
# 수단🇸🇩
# 몰타 공화국🇲🇹
# 모리타니🇲🇷
# 카보베르데🇨🇻
# 가이아나🇬🇾
# 가봉🇬🇦
# 파푸아뉴기니🇵🇬
# 기니🇬🇳
# 벨리즈🇧🇿
# 탄자니아🇹🇿
# 토고🇹🇬
# 아이티🇭🇹
# 바베이도스🇧🇧
# 베냉🇧🇯
# 세이셸🇸🇨
# 소말리아🇸🇴
# 바하마🇧🇸
# 레소토🇱🇸
# 모리셔스🇲🇺
# 마요트🇾🇹
# 부룬디🇧🇮
# 동티모르🇹🇱
# 콩고공화국🇨🇬
# 아이슬란드🇮🇸
# 퀴라소🇨🇼
# 말리🇲🇱
# 니카라과🇳🇮
# 타지키스탄🇹🇯
# 안도라🇦🇩
# 대만🇹🇼
# 아루바🇦🇼
# 부르키나파소🇧🇫
# 브루나이🇧🇳
# 적도 기니🇬🇶
# 지부티🇩🇯
# 세인트루시아🇱🇨
# 남수단🇸🇸
# 홍콩🇭🇰
# 중앙아프리카 공화국🇨🇫
# 뉴질랜드🇳🇿
# 맨섬🇮🇲
# 감비아🇬🇲
# 예멘🇾🇪
# 에리트레아🇪🇷
# 지브롤터🇬🇮
# 뉴칼레도니아🇳🇨
# 니제르🇳🇪
# 케이맨 제도🇰🇾
# 기니비사우🇬🇼
# 시에라리온🇸🇱
# 그레나다🇬🇩
# 라이베리아🇱🇷
# 도미니카 연방🇩🇲
# 산마리노🇸🇲
# 버뮤다🇧🇲
# 세인트빈센트 그레나딘🇻🇨
# 차드🇹🇩
# 신트마르턴🇸🇽
# 리히텐슈타인🇱🇮
# 코모로🇰🇲
# 앤티가 바부다🇦🇬
# 세인트마틴 섬🇲🇫
# 상투메 프린시페🇸🇹
# 모나코🇲🇨
# 페로 제도🇫🇴
# 터크스 케이커스 제도🇹🇨
# 카리브 네덜란드🇧🇶
# 세인트키츠 네비스🇰🇳
# 영국령 버진아일랜드🇻🇬
# 부탄🇧🇹
# 생바르텔레미🇧🇱
# 앵귈라🇦🇮
# 그린란드🇬🇱
# 왈리스 퓌티나🇼🇫
# 포클랜드 제도🇫🇰
# 마카오🇲🇴
# 생피에르 미클롱🇵🇲
# 몬트세랫🇲🇸
# 바티칸 시국🇻🇦
# 솔로몬 제도🇸🇧
# 서사하라🇪🇭
# 잔담(크루즈)🚢
# 팔라우🇵🇼
# 바누아투🇻🇺
# 마셜 제도🇲🇭
# 사모아🇼🇸
# 세인트헬레나🇸🇭
# 미크로네시아🇫🇲
# 통가🇹🇴

# %% [markdown]
# ### 확진자 정보
#  * //*[@id="country-table"]/div/div/table/tbody/tr[1]/td[3]
#  * //*[@id="country-table"]/div/div/table/tbody/tr[2]/td[3]
#  * ..
#  * //*[@id="country-table"]/div/div/table/tbody/tr[5]/td[3]
#
#
# ### 치료중
#  * //*[@id="country-table"]/div/div/table/tbody/tr[1]/td[4]
#  * //*[@id="country-table"]/div/div/table/tbody/tr[3]/td[4]
#  * ..
#
# ### 위중증
#  * //*[@id="country-table"]/div/div/table/tbody/tr[1]/td[5]
#  * //*[@id="country-table"]/div/div/table/tbody/tr[3]/td[5]
#  * ..
#
# ### 사망자 정보
#  * //*[@id="country-table"]/div/div/table/tbody/tr[1]/td[6]
#  * //*[@id="country-table"]/div/div/table/tbody/tr[2]/td[6]
#  * ...
#
# ### 완치
#  * //*[@id="country-table"]/div/div/table/tbody/tr[1]/td[7]
#  * //*[@id="country-table"]/div/div/table/tbody/tr[2]/td[7]
#  * ..
#
# ### 치명(%)
#  * //*[@id="country-table"]/div/div/table/tbody/tr[1]/td[8]
#  * //*[@id="country-table"]/div/div/table/tbody/tr[2]/td[8]
#  * ...
#
# ### 완치(%)
#  * //*[@id="country-table"]/div/div/table/tbody/tr[2]/td[9]
#
#
# ### 발생률
#  * //*[@id="country-table"]/div/div/table/tbody/tr[1]/td[10]
#  * //*[@id="country-table"]/div/div/table/tbody/tr[2]/td[10]
#  * ...
#
# ### 인구수
#  * //*[@id="country-table"]/div/div/table/tbody/tr[1]/td[11]
#  * //*[@id="country-table"]/div/div/table/tbody/tr[2]/td[11]
#  * ...

# %% [markdown]
# ### 어제 오늘 선택

# %%
# 어제 : //*[@id="global-slide"]/div/div[2]/ul/li[2]/a
flag_today = False # False : 어제, Today : 오늘

# %%
# 어제일 경우에만 버튼을 선택
if flag_today==False:
    sel_yesterday = driver.find_element_by_xpath('//*[@id="global-slide"]/div/div[2]/ul/li[2]/a')
    sel_yesterday.click()

# %% [markdown]
# ### 전체 데이터 가져오기

# %%
all_data = []
for i in range(2, 12):
    tmp = '//*[@id="country-table"]/div/div/table/tbody/tr/td[{}]'.format(i)
    # print(tmp)
    sel_ele = driver.find_elements_by_xpath(tmp)
    
    
    column_data = []
    for one in sel_ele:
        # print(one.text)
        column_data.append(one.text)
    
    print( len(sel_ele) )
    all_data.append(column_data)
    print(column_data)
    print()
    
all_data
# Out:
# 223
# ['미국🇺🇸', '인도🇮🇳', '브라질🇧🇷', '영국🇬🇧', '러시아🇷🇺', '터키🇹🇷', '프랑스🇫🇷', '이란🇮🇷', '독일🇩🇪', '아르헨티나🇦🇷', '스페인🇪🇸', '콜롬비아🇨🇴', '이탈리아🇮🇹', '인도네시아🇮🇩', '멕시코🇲🇽', '폴란드🇵🇱', '우크라이나🇺🇦', '남아프리카 공화국🇿🇦', '필리핀🇵🇭', '말레이시아🇲🇾', '네덜란드🇳🇱', '페루🇵🇪', '체코🇨🇿', '태국🇹🇭', '이라크🇮🇶', '캐나다🇨🇦', '루마니아🇷🇴', '칠레🇨🇱', '일본🇯🇵*', '벨기에🇧🇪', '방글라데시🇧🇩', '이스라엘🇮🇱', '파키스탄🇵🇰', '세르비아🇷🇸', '베트남🇻🇳', '스웨덴🇸🇪', '오스트리아🇦🇹', '포르투갈🇵🇹', '헝가리🇭🇺', '스위스🇨🇭', '카자흐스탄🇰🇿', '쿠바🇨🇺', '모로코🇲🇦', '요르단🇯🇴', '그리스🇬🇷', '조지아🇬🇪', '네팔🇳🇵', '아랍에미레이트🇦🇪', '튀니지🇹🇳', '불가리아🇧🇬', '슬로바키아🇸🇰', '레바논🇱🇧', '벨라루스🇧🇾', '과테말라🇬🇹', '크로아티아🇭🇷', '아제르바이잔🇦🇿', '코스타리카🇨🇷', '스리랑카🇱🇰', '아일랜드🇮🇪', '사우디아라비아🇸🇦', '볼리비아🇧🇴', '에콰도르🇪🇨', '미얀마🇲🇲', '덴마크🇩🇰', '파나마🇵🇦', '리투아니아🇱🇹', '파라과이🇵🇾', '대한민국🇰🇷', '베네수엘라🇻🇪', '팔레스타인🇵🇸', '슬로베니아🇸🇮', '쿠웨이트🇰🇼', '도미니카 공화국🇩🇴', '우루과이🇺🇾', '몽골🇲🇳', '온두라스🇭🇳', '리비아🇱🇾', '에티오피아🇪🇹', '몰도바🇲🇩', '이집트🇪🇬', '아르메니아🇦🇲', '오만🇴🇲', '바레인🇧🇭', '보스니아 헤르체고비나🇧🇦', '싱가포르🇸🇬', '노르웨이🇳🇴', '케냐🇰🇪', '라트비아🇱🇻', '카타르🇶🇦', '에스토니아🇪🇪', '북마케도니아🇲🇰', '나이지리아🇳🇬', '잠비아🇿🇲', '알제리🇩🇿', '호주🇦🇺', '알바니아🇦🇱', '보츠와나🇧🇼', '우즈베키스탄🇺🇿', '키르기스스탄🇰🇬', '핀란드🇫🇮', '아프가니스탄🇦🇫', '몬테네그로🇲🇪', '모잠비크🇲🇿', '짐바브웨🇿🇼', '키프로스🇨🇾', '가나🇬🇭', '나미비아🇳🇦', '우간다🇺🇬', '캄보디아🇰🇭', '엘살바도르🇸🇻', '코소보🇽🇰', '카메룬🇨🇲', '르완다🇷🇼', '중국🇨🇳', '몰디브🇲🇻', '자메이카🇯🇲', '룩셈부르크🇱🇺', '세네갈🇸🇳', '라오스🇱🇦', '트리니다드 토바고🇹🇹', '앙골라🇦🇴', '말라위🇲🇼', '코트디부아르🇨🇮', '레위니옹🇷🇪', '콩고민주공화국🇨🇩', '과들루프🇬🇵', '피지🇫🇯', '수리남🇸🇷', '시리아🇸🇾', '에스와티니🇸🇿', '프랑스령 기아나🇬🇫', '프랑스령 폴리네시아🇵🇫', '마르티니크🇲🇶', '마다가스카르🇲🇬', '수단🇸🇩', '몰타 공화국🇲🇹', '모리타니🇲🇷', '카보베르데🇨🇻', '가이아나🇬🇾', '가봉🇬🇦', '파푸아뉴기니🇵🇬', '기니🇬🇳', '벨리즈🇧🇿', '탄자니아🇹🇿', '토고🇹🇬', '아이티🇭🇹', '바베이도스🇧🇧', '베냉🇧🇯', '세이셸🇸🇨', '소말리아🇸🇴', '바하마🇧🇸', '레소토🇱🇸', '모리셔스🇲🇺', '마요트🇾🇹', '부룬디🇧🇮', '동티모르🇹🇱', '콩고공화국🇨🇬', '아이슬란드🇮🇸', '퀴라소🇨🇼', '말리🇲🇱', '니카라과🇳🇮', '타지키스탄🇹🇯', '안도라🇦🇩', '대만🇹🇼', '아루바🇦🇼', '부르키나파소🇧🇫', '브루나이🇧🇳', '적도 기니🇬🇶', '지부티🇩🇯', '세인트루시아🇱🇨', '남수단🇸🇸', '홍콩🇭🇰', '중앙아프리카 공화국🇨🇫', '뉴질랜드🇳🇿', '맨섬🇮🇲', '감비아🇬🇲', '예멘🇾🇪', '에리트레아🇪🇷', '지브롤터🇬🇮', '뉴칼레도니아🇳🇨', '니제르🇳🇪', '케이맨 제도🇰🇾', '기니비사우🇬🇼', '시에라리온🇸🇱', '그레나다🇬🇩', '라이베리아🇱🇷', '도미니카 연방🇩🇲', '산마리노🇸🇲', '버뮤다🇧🇲', '세인트빈센트 그레나딘🇻🇨', '차드🇹🇩', '신트마르턴🇸🇽', '리히텐슈타인🇱🇮', '코모로🇰🇲', '앤티가 바부다🇦🇬', '세인트마틴 섬🇲🇫', '상투메 프린시페🇸🇹', '모나코🇲🇨', '페로 제도🇫🇴', '터크스 케이커스 제도🇹🇨', '카리브 네덜란드🇧🇶', '세인트키츠 네비스🇰🇳', '영국령 버진아일랜드🇻🇬', '부탄🇧🇹', '생바르텔레미🇧🇱', '앵귈라🇦🇮', '그린란드🇬🇱', '왈리스 퓌티나🇼🇫', '포클랜드 제도🇫🇰', '마카오🇲🇴', '생피에르 미클롱🇵🇲', '몬트세랫🇲🇸', '바티칸 시국🇻🇦', '솔로몬 제도🇸🇧', '서사하라🇪🇭', '잔담(크루즈)🚢', '팔라우🇵🇼', '바누아투🇻🇺', '마셜 제도🇲🇭', '사모아🇼🇸', '세인트헬레나🇸🇭', '미크로네시아🇫🇲', '통가🇹🇴']
#
# 223
# ['49,077,695\n(+26,778)', '34,572,523\n(+8,774)', '22,076,863\n(+9,233)', '10,110,408\n(+39,567)', '9,570,373\n(+33,548)', '8,724,400\n(+23,759)', '7,588,400\n(+37,218)', '6,108,882\n(+3,781)', '5,754,967\n(+40,481)', '5,325,560\n(+1,521)', '5,131,012', '5,063,177\n(+2,620)', '4,994,891\n(+12,869)', '4,255,936\n(+264)
', '13,742', '15,955\n(+22)', '15,211\n(+202)', '14,367', '13,323', '13,291', '12,562\n(+9)', '12,395', '12,130\n(+2)', '6,859', '5,635\n(+68)', '10,363', '9,638', '6,845\n(+16)', '7,076\n(+28)', '6,632\n(+144)', '58', '6,541\n(+6)', '2,550', '6,259\n(+1)', '4,393', '5,622', '5,523', '5,396', '5,519', '5,603', '4,991', '4,874', '4,480\n(+2)', '3,958', '4,273', '4,000', '1,399', '3,675', '3,517\n(+15)', '3,015', '3,021', '2,623\n(+30)', '2,723', 'N/A', '2,620', 'N/A', '1,207', '1,011', '438', 'N/A', '77', '32', '41', '27', '20', '8', '7', '8', '3', '4', '3', '2', '1', '1']
#
# 223
# ['1.6', '1.4', '2.8', '1.4', '2.8', '0.9', '1.6', '2.1', '1.8', '2.2', '1.7', '2.5', '2.7', '3.4', '7.6', '2.4', '2.5', '3.0', '1.7', '1.2', '0.7', '9.0', '1.5', '1.0', '1.1', '1.7', '3.2', '2.2', '1.1', '1.6', '1.8', '0.6', '2.2', '0.9', '2.1', '1.3', '1.1', '1.6', '3.2', '1.2', '1.3', '0.9', '1.6', '1.2', '1.9', '1.4', '1.4', '0.3', '3.5', '4.1', '2.1', '1.3', '0.8', '2.6', '1.8', '1.3', '1.3', '2.5', '1.0', '1.6', '3.6', '6.3', '3.7', '0.6', '1.5', '1.4', '3.6', '0.8', '1.2', '1.1', '1.2', '0.6', '1.0', '1.5', '0.5', '2.8', '1.5', '1.8', '2.5', '5.7', '2.2', '1.4', '0.5', '4.6', '0.3', '0.4', '2.1', '1.6', '0.3', '0.8', '3.5', '1.4', '1.7', '2.9', '1.0', '1.5', '1.2', '0.7', '1.5', '0.7', '4.6', '1.5', '1.3', '3.5', '0.4', '0.9', '2.8', '2.6', '2.4', '3.2', '2.1', '1.7', '1.3', '4.7', '0.3', '2.6', '1.0', '2.5', '0.2', '3.0', '2.7', '3.7', '1.1', '0.6', '1.9', '1.4', '1.3', '2.3', '5.7', '2.7', '0.7', '1.4', '1.6', '2.2', '7.4', '1.2', '2.1', '0.9', '2.6', '0.7', '1.6', '1.3', '1.9', '2.8', '0.9', '2.9', '0.9', '0.6', '0.5', '5.8', '3.0', '3.0', '2.1', '0.9', '0.2', '0.6', '1.9', '0.2', '1.0', '3.5', '1.2', '0.7', '0.8', '5.1', '1.1', '1.8', '0.6', '1.3', '1.4', '2.2', '1.0', '1.7', '0.9', '0.4', '0.6', '3.4', '19.5', '0.8', '1.4', '1.6', '3.7', '0.1', '2.3', '1.9', '3.4', '4.9', '0.6', '1.6', '1.8', '1.3', '3.4', '1.6', '1.4', '3.3', '2.8', '1.4', '1.5', '1.0', '0.4', '0.8', '0.8', '1.0', '1.4', '0.1', '0.4', '0.2', '-', '1.6', '-', '-', '-', '2.3', '-', '-', '10', '22.2', '-', '16.7', '-', '-', '-', '-', '-']
# 223
'1,271,768', '272,815', '11,890,784', '1,318,445', '5,518,087', '341,243', '164,093', '20,250,833', '6,624,554', '9,537,645', '77,265', '23,816,775', '106,766', '20,903,273', '437,479', '1,402,985', '988,000', '183,627', '11,193,725', '7,496,981', '4,829,767', '4,822,233', '85,033', '2,416,668', '29,825,964', '3,546,421', '33,691', '285,498', '24,206,644', '65,722', '1,968,001', '7,976,983', '112,523', '5,057,681', '71,986', '33,931', '62,278', '110,940', '16,425,864', '42,876', '38,128', '869,601', '97,929', '38,666', '219,159', '39,242', '48,863', '38,717', '26,223', '53,199', '30,231', '771,608', '9,877', '15,003', '56,770', '-', '3,480', '649,335', '5,794', '4,992', '801', '686,884', '597,339', '-', '18,094', '307,145', '59,190', '198,414', '6,077', '115,023', '105,695']
# [['미국🇺🇸',
#   '인도🇮🇳',
#   '브라질🇧🇷',
#   '영국🇬🇧',
#   '러시아🇷🇺',
#   '터키🇹🇷',
#   '프랑스🇫🇷',
#   '이란🇮🇷',
#   '독일🇩🇪',
#   '아르헨티나🇦🇷',
#   '스페인🇪🇸',
#   '콜롬비아🇨🇴',
#   '이탈리아🇮🇹',
#   '인도네시아🇮🇩',
#   '멕시코🇲🇽',
#   '폴란드🇵🇱',
#   '우크라이나🇺🇦',
#   '남아프리카 공화국🇿🇦',
#   '필리핀🇵🇭',
#   '말레이시아🇲🇾',
#   '네덜란드🇳🇱',
#   '페루🇵🇪',
#   '체코🇨🇿',
#   '태국🇹🇭',
#   '이라크🇮🇶',
#   '캐나다🇨🇦',
#   '루마니아🇷🇴',
#   '칠레🇨🇱',
#   '일본🇯🇵*',
#   '벨기에🇧🇪',
#   '방글라데시🇧🇩',
#   '이스라엘🇮🇱',
#   '파키스탄🇵🇰',
#   '세르비아🇷🇸',
#   '베트남🇻🇳',
#   '스웨덴🇸🇪',
#   '오스트리아🇦🇹',
#   '포르투갈🇵🇹',
#   '헝가리🇭🇺',
#   '스위스🇨🇭',
#   '카자흐스탄🇰🇿',
#   '쿠바🇨🇺',
#   '모로코🇲🇦',
#   '요르단🇯🇴',
#   '그리스🇬🇷',
#   '조지아🇬🇪',
#   '네팔🇳🇵',
#   '아랍에미레이트🇦🇪',
#   '튀니지🇹🇳',
#   '불가리아🇧🇬',
#   '슬로바키아🇸🇰',
#   '레바논🇱🇧',
#   '벨라루스🇧🇾',
#   '과테말라🇬🇹',
#   '크로아티아🇭🇷',
#   '아제르바이잔🇦🇿',
#   '코스타리카🇨🇷',
#   '스리랑카🇱🇰',
#   '아일랜드🇮🇪',
#   '사우디아라비아🇸🇦',
#   '볼리비아🇧🇴',
#   '에콰도르🇪🇨',
#   '미얀마🇲🇲',
#   '덴마크🇩🇰',
#   '파나마🇵🇦',
#   '리투아니아🇱🇹',
#   '파라과이🇵🇾',
#   '대한민국🇰🇷',
#   '베네수엘라🇻🇪',
#   '팔레스타인🇵🇸',
#   '슬로베니아🇸🇮',
#   '쿠웨이트🇰🇼',
#   '도미니카 공화국🇩🇴',
#   '우루과이🇺🇾',
#   '몽골🇲🇳',
#   '온두라스🇭🇳',
#   '리비아🇱🇾',
#   '에티오피아🇪🇹',
#   '몰도바🇲🇩',
#   '이집트🇪🇬',
#   '아르메니아🇦🇲',
#   '오만🇴🇲',
#   '바레인🇧🇭',
#   '보스니아 헤르체고비나🇧🇦',
#   '싱가포르🇸🇬',
#   '노르웨이🇳🇴',
#   '케냐🇰🇪',
#   '라트비아🇱🇻',
#   '카타르🇶🇦',
#   '에스토니아🇪🇪',
#   '북마케도니아🇲🇰',
#   '나이지리아🇳🇬',
#   '잠비아🇿🇲',
#   '알제리🇩🇿',
#   '호주🇦🇺',
#   '알바니아🇦🇱',
#   '보츠와나🇧🇼',
#   '우즈베키스탄🇺🇿',
#   '키르기스스탄🇰🇬',
#   '핀란드🇫🇮',
#   '아프가니스탄🇦🇫',
#   '몬테네그로🇲🇪',
#   '모잠비크🇲🇿',
#   '짐바브웨🇿🇼',
#   '키프로스🇨🇾',
#   '가나🇬🇭',
#   '나미비아🇳🇦',
#   '우간다🇺🇬',
#   '캄보디아🇰🇭',
#   '엘살바도르🇸🇻',
#   '코소보🇽🇰',
#   '카메룬🇨🇲',
#   '르완다🇷🇼',
#   '중국🇨🇳',
#   '몰디브🇲🇻',
#   '자메이카🇯🇲',
#   '룩셈부르크🇱🇺',
#   '세네갈🇸🇳',
#   '라오스🇱🇦',
#   '트리니다드 토바고🇹🇹',
#   '앙골라🇦🇴',
#   '말라위🇲🇼',
#   '코트디부아르🇨🇮',
#   '레위니옹🇷🇪',
#   '콩고민주공화국🇨🇩',
#   '과들루프🇬🇵',
#   '피지🇫🇯',
#   '수리남🇸🇷',
#   '시리아🇸🇾',
#   '에스와티니🇸🇿',
#   '프랑스령 기아나🇬🇫',
#   '프랑스령 폴리네시아🇵🇫',
#   '마르티니크🇲🇶',
#   '마다가스카르🇲🇬',
#   '수단🇸🇩',
#   '몰타 공화국🇲🇹',
#   '모리타니🇲🇷',
#   '카보베르데🇨🇻',
#   '가이아나🇬🇾',
#   '가봉🇬🇦',
#   '파푸아뉴기니🇵🇬',
#   '기니🇬🇳',
#   '벨리즈🇧🇿',
#   '탄자니아🇹🇿',
#   '토고🇹🇬',
#   '아이티🇭🇹',
#   '바베이도스🇧🇧',
#   '베냉🇧🇯',
#   '세이셸🇸🇨',
#   '소말리아🇸🇴',
#   '바하마🇧🇸',
#   '레소토🇱🇸',
#   '모리셔스🇲🇺',
#   '마요트🇾🇹',
#   '부룬디🇧🇮',
#   '동티모르🇹🇱',
#   '콩고공화국🇨🇬',
#   '아이슬란드🇮🇸',
#   '퀴라소🇨🇼',
#   '말리🇲🇱',
#   '니카라과🇳🇮',
#   '타지키스탄🇹🇯',
#   '안도라🇦🇩',
#   '대만🇹🇼',
#   '아루바🇦🇼',
#   '부르키나파소🇧🇫',
#   '브루나이🇧🇳',
#   '적도 기니🇬🇶',
#   '지부티🇩🇯',
#   '세인트루시아🇱🇨',
#   '남수단🇸🇸',
#   '홍콩🇭🇰',
#   '중앙아프리카 공화국🇨🇫',
#   '뉴질랜드🇳🇿',
#   '맨섬🇮🇲',
#   '감비아🇬🇲',
#   '예멘🇾🇪',
#   '에리트레아🇪🇷',
#   '지브롤터🇬🇮',
#   '뉴칼레도니아🇳🇨',
#   '니제르🇳🇪',
#   '케이맨 제도🇰🇾',
#   '기니비사우🇬🇼',
#   '시에라리온🇸🇱',
#   '그레나다🇬🇩',
#   '라이베리아🇱🇷',
#   '도미니카 연방🇩🇲',
#   '산마리노🇸🇲',
#   '버뮤다🇧🇲',
#   '세인트빈센트 그레나딘🇻🇨',
#   '차드🇹🇩',
#   '신트마르턴🇸🇽',
#   '리히텐슈타인🇱🇮',
#   '코모로🇰🇲',
#   '앤티가 바부다🇦🇬',
#   '세인트마틴 섬🇲🇫',
#   '상투메 프린시페🇸🇹',
#   '모나코🇲🇨',
#   '페로 제도🇫🇴',
#   '터크스 케이커스 제도🇹🇨',
#   '카리브 네덜란드🇧🇶',
#   '세인트키츠 네비스🇰🇳',
#   '영국령 버진아일랜드🇻🇬',
#   '부탄🇧🇹',
#   '생바르텔레미🇧🇱',
#   '앵귈라🇦🇮',
#   '그린란드🇬🇱',
#   '왈리스 퓌티나🇼🇫',
#   '포클랜드 제도🇫🇰',
#   '마카오🇲🇴',
#   '생피에르 미클롱🇵🇲',
#   '몬트세랫🇲🇸',
#   '바티칸 시국🇻🇦',
#   '솔로몬 제도🇸🇧',
#   '서사하라🇪🇭',
#   '잔담(크루즈)🚢',
#   '팔라우🇵🇼',
#   '바누아투🇻🇺',
#   '마셜 제도🇲🇭',
#   '사모아🇼🇸',
#   '세인트헬레나🇸🇭',
#   '미크로네시아🇫🇲',
#   '통가🇹🇴'],
#  ['49,077,695\n(+26,778)',
#   '34,572,523\n(+8,774)',
#   '22,076,863\n(+9,233)',
#   '10,110,408\n(+39,567)',
#   '9,570,373\n(+33,548)',
#   '8,724,400\n(+23,759)',
#   '7,588,400\n(+37,218)',
#   '6,108,882\n(+3,781)',
#   '5,754,967\n(+40,481)',
#   '5,325,560\n(+1,521)',
#   '5,131,012',
#   '5,063,177\n(+2,620)',
#   '4,994,891\n(+12,869)',
#   '4,255,936\n(+264)',
#   '3,882,792\n(+2,956)',
#   '3,507,828\n(+20,574)',
#   '3,422,023\n(+7,483)',
#   '2,958,548\n(+3,220)',
#   '2,831,807\n(+630)',
#   '2,619,577\n(+5,097)',
#   '2,599,579\n(+22,133)',
#   '2,232,749\n(+3,008)',
#   '2,123,059\n(+12,785)',
#   '2,106,813\n(+5,854)',
#   '2,079,622\n(+538)',
#   '1,784,354\n(+2,183)',
#   '1,776,949\n(+1,377)',
#   '1,757,077',
#   '1,727,504\n(+72)',
#   '1,701,633',
#   '1,575,784\n(+205)',
#   '1,341,881\n(+340)',
#   '1,284,189\n(+303)',
#   '1,250,393\n(+1,674)',
#   '1,210,340\n(+12,936)',
#   '1,198,848',
#   '1,143,283\n(+10,478)',
#   '1,139,810\n(+3,364)',
#   '1,068,888',
#   '982,290',
#   '970,092\n(+847)',
#   '962,067\n(+183)',
#   '949,648\n(+116)',
#   '939,293',
#   '920,683\n(+5,859)',
#   '838,639\n(+3,333)',
#   '820,878\n(+154)',
#   '741,918\n(+60)',
#   '717,163\n(+175)',
#   '688,628\n(+1,218)',
#   '667,961\n(+7,575)',
#   '666,768\n(+1,515)',
#   '651,839\n(+1,671)',
#   '617,495\n(+458)',
#   '603,316\n(+8,841)',
#   '585,783\n(+1,662)',
#   '566,560',
#   '562,310\n(+732)',
#   '560,054\n(+3,735)',
#   '549,695\n(+24)',
#   '535,115',
#   '524,432',
#   '521,211\n(+505)',
#   '478,927\n(+4,290)',
#   '477,306\n(+210)',
#   '467,900\n(+1,292)',
#   '462,908\n(+53)',
#   '440,896\n(+3,928)',
#   '430,046\n(+686)',
#   '429,333',
#   '417,376\n(+1,478)',
#   '413,266\n(+21)',
#   '406,511\n(+490)',
#   '399,181\n(+291)',
#   '380,945\n(+329)',
#   '377,888',
#   '371,571\n(+784)',
#   '371,177\n(+119)',
#   '362,326\n(+498)',
#   '355,767\n(+931)',
#   '337,931\n(+409)',
#   '304,519',
#   '277,552\n(+16)',
#   '272,798',
#   '261,636\n(+1,761)',
#   '259,200\n(+1,891)',
#   '254,951\n(+47)',
#   '252,413\n(+488)',
#   '243,132\n(+153)',
#   '221,549\n(+389)',
#   '214,676\n(+463)',
#   '213,982\n(+58)',
#   '210,143\n(+5)',
#   '209,980\n(+163)',
#   '208,004\n(+1,260)',
#   '199,137\n(+405)',
#   '194,909',
#   '192,831\n(+232)',
#   '183,248\n(+108)',
#   '182,284',
#   '157,218\n(+28)',
#   '156,608\n(+340)',
#   '151,515',
#   '133,951\n(+115)',
#   '131,462',
#   '130,920',
#   '129,180\n(+29)',
#   '127,451\n(+28)',
#   '120,087\n(+23)',
#   '118,919\n(+878)',
#   '107,507',
#   '106,794',
#   '100,325\n(+14)',
#   '98,650\n(+42)',
#   '91,350\n(+76)',
#   '91,122\n(+96)',
#   '88,108',
#   '73,985\n(+4)',
#   '71,518\n(+2,686)',
#   '69,680\n(+672)',
#   '65,139\n(+9)',
#   '61,889\n(+3)',
#   '61,704\n(+18)',
#   '59,048',
#   '58,115',
#   '55,147',
#   '52,494',
#   '50,741\n(+31)',
#   '47,764',
#   '46,528\n(+4)',
#   '45,864',
#   '45,609',
#   '44,318',
#   '44,072',
#   '42,056',
#   '39,234\n(+72)',
#   '39,115\n(+80)',
#   '38,358\n(+5)',
#   '37,707\n(+44)',
#   '37,298\n(+75)',
#   '35,029\n(+123)',
#   '30,763',
#   '30,165',
#   '26,261',
#   '26,241\n(+5)',
#   '25,027',
#   '24,923\n(+154)',
#   '24,850',
#   '23,197',
#   '23,016',
#   '22,734',
#   '21,755',
#   '21,191\n(+151)',
#   '20,938',
#   '20,386',
#   '19,822',
#   '18,837',
#   '17,446',
#   '17,390\n(+6)',
#   '17,300\n(+81)',
#   '17,152',
#   '17,095',
#   '16,712',
#   '16,588\n(+10)',
#   '16,312\n(+21)',
#   '15,711\n(+197)',
#   '14,992',
#   '13,579',
#   '13,504',
#   '12,970\n(+16)',
#   '12,717',
#   '12,427\n(+3)',
#   '11,708',
#   '11,260\n(+146)',
#   '11,085\n(+92)',
#   '9,989',
#   '9,987\n(+6)',
#   '7,305\n(+20)',
#   '7,179\n(+17)',
#   '7,176',
#   '6,958\n(+25)',
#   '6,738',
#   '6,440\n(+1)',
#   '6,400',
#   '5,888\n(+4)',
#   '5,821',
#   '5,819',
#   '5,790',
#   '5,730',
#   '5,500',
#   '5,105',
#   '4,575\n(+2)',
#   '4,507\n(+47)',
#   '4,489',
#   '4,141',
#   '3,949',
#   '3,731',
#   '3,728\n(+23)',
#   '3,408',
#   '3,096',
#   '2,869\n(+11)',
#   '2,779',
#   '2,765',
#   '2,640\n(+4)',
#   '1,601',
#   '1,334',
#   '1,332',
#   '445',
#   '79',
#   '77',
#   '59',
#   '44',
#   '27',
#   '20',
#   '10',
#   '9',
#   '8',
#   '6',
#   '4',
#   '3',
#   '2',
#   '1',
#   '1'],
#  ['9,416,669\n(+5,573)',
#   '105,691\n(-1,328)',
#   '174,346\n(+3,520)',
#   '1,013,851\n(+27)',
#   '1,029,507\n(+1,678)',
#   '389,564\n(-1,536)',
#   '370,916\n(+28,671)',
#   '116,005\n(-6,481)',
#   '829,899\n(+19,749)',
#   '19,536\n(+160)',
#   '128,771',
#   '31,552\n(-60)',
#   '178,946\n(+6,328)',
#   '8,214\n(-12)',
#   '350,375\n(+671)',
#   '424,479\n(-1,681)',
#   '426,669\n(-3,187)',
#   '21,674\n(+1,736)',
#   '16,630\n(-422)',
#   '67,252\n(-295)',
#   'N/A',
#   'N/A',
#   '267,434\n(-297)',
#   '79,252\n(-530)',
#   '13,530\n(-804)',
#   '26,396\n(+1,369)',
#   '40,732\n(-3,487)',
#   '68,623',
#   '725\n(-61)',
#   '367,639',
#   '7,489\n(-97)',
#   '6,651\n(+338)',
#   '13,719\n(+126)',
#   '53,260\n(-2,930)',
#   '226,822\n(+11,034)',
#   'N/A',
#   '148,603\n(-3,668)',
#   '51,689\n(+809)',
#   '172,488',
#   '114,160\n(-1,800)',
#   '23,439\n(-48)',
#   '1,028\n(-49)',
#   '2,991\n(-56)',
#   '49,622',
#   '81,542\n(-1,322)',
#   '47,202\n(-1,775)',
#   '6,966\n(-190)',
#   '2,994\n(-20)',
#   '1,093\n(+38)',
#   '105,142\n(+24)',
#   '107,815\n(+1,725)',
#   '26,773\n(+852)',
#   '7,941\n(-533)',
#   '1,752\n(-68)',
#   '34,326\n(-405)',
#   '26,252\n(-747)',
#   '15,398',
#   '18,343\n(+283)',
#   '117,756\n(+1,184)',
#   '2,006\n(-9)',
#   '25,457',
#   '47,424',
#   '6,724\n(-167)',
#   '72,937\n(+4,281)',
#   '2,660\n(-4)',
#   '29,024\n(+995)',
#   '859\n(-51)',
#   '45,037\n(+1,702)',
#   '7,778\n(-225)',
#   '2,695',
#   '39,204\n(-890)',
#   '226\n(-8)',
#   '3,581\n(-365)',
#   '2,144\n(+97)',
#   '65,699\n(+324)',
#   '247,177',
#   '24,410\n(-1,944)',
#   '16,142\n(-101)',
#   '7,205\n(-375)',
#   '40,028\n(+332)',
#   '15,291\n(-726)',
#   '455',
#   '269\n(-8)',
#   '68,124',
#   '14,684\n(-142)',
#   '169,198\n(+1,891)',
#   '1,488\n(+1)',
#   '11,689\n(-265)',
#   '1,994\n(+25)',
#   '18,911\n(-295)',
#   '8,393\n(+110)',
#   '3,823\n(-12)',
#   '90\n(-10)',
#   '59,899\n(+30)',
#   '15,444\n(+484)',
#   '7,459\n(-151)',
#   '532',
#   '1,986\n(+41)',
#   '2,459\n(-75)',
#   '134,975',
#   '9,446\n(+15)',
#   '2,858\n(-74)',
#   '104',
#   '600\n(+95)',
#   '6,501',
#   '669',
#   '124\n(+10)',
#   '26,352\n(-390)',
#   '690\n(-1)',
#   '13,133\n(-52)',
#   '-85',
#   '2,287',
#   '53,462\n(+13)',
#   '804\n(-5)',
#   '1,807\n(-29)',
#   '26,390\n(-3)',
#   '3,984',
#   '13\n(+1)',
#   '64,020\n(+2,674)',
#   '10,342\n(+337)',
#   '214',
#   '822\n(+3)',
#   '316\n(-2)',
#   '2,627',
#   '6,081',
#   '52,151',
#   '807',
#   '20,010\n(+28)',
#   '16,241',
#   '42\n(+4)',
#   '34,284',
#   '11,473',
#   '43,514',
#   '1,783',
#   '6,037',
#   '1,473\n(+29)',
#   '958\n(+14)',
#   '72\n(-1)',
#   '1,480\n(+24)',
#   '5,000\n(-311)',
#   '656\n(-207)',
#   '651',
#   '1,174',
#   '25,531',
#   '98',
#   '3,331',
#   '3,903\n(-474)',
#   '143',
#   '482',
#   '9,643',
#   '459',
#   '7,436',
#   '1,431\n(+2)',
#   '17,789',
#   '19,575',
#   '3\n(-1)',
#   '6,067',
#   '1,746',
#   '110\n(-10)',
#   '1,583\n(+51)',
#   '12,718',
#   '5',
#   '811',
#   '1,998\n(+10)',
#   '183\n(-1)',
#   '219\n(-21)',
#   '528',
#   '83',
#   '27',
#   '128\n(+7)',
#   '189',
#   '84\n(+1)',
#   '4,748',
#   '5,582\n(+77)',
#   '656\n(+92)',
#   '9',
#   '1,196\n(-11)',
#   '169\n(-8)',
#   '449\n(-127)',
#   '7,004',
#   '163\n(+19)',
#   '4,184',
#   '35',
#   '1,886',
#   '66\n(+4)',
#   '11',
#   '386',
#   '178',
#   '21',
#   '435',
#   '56',
#   '20',
#   '488\n(+47)',
#   '66',
#   '24',
#   '2,494',
#   '0',
#   '175\n(+8)',
#   '380',
#   '51',
#   '224\n(-19)',
#   '28',
#   'N/A',
#   '17\n(+4)',
#   'N/A',
#   '124',
#   '321',
#   '0',
#   'N/A',
#   '0',
#   '27',
#   '2',
#   '0',
#   '0',
#   '1',
#   '0',
#   '0',
#   '2',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'],
#  ['12,438\n(+130)',
#   '8,944',
#   '8,318',
#   '925',
#   '2,300',
#   '1,405',
#   '1,563',
#   '3,347\n(-9)',
#   '4,202',
#   '593\n(+3)',
#   '597',
#   '342',
#   '624\n(+18)',
#   'N/A',
#   '4,798',
#   '1,816\n(+64)',
#   '177',
#   '546',
#   '1,023\n(-147)',
#   '510\n(-9)',
#   '546\n(+6)',
#   '954\n(+25)',
#   '948\n(+24)',
#   '1,595',
#   '109\n(-5)',
#   '480',
#   '1,212\n(-53)',
#   '674',
#   '47\n(-7)',
#   '669',
#   '1,384\n(+22)',
#   '128',
#   '946\n(+11)',
#   '209\n(-3)',
#   '6,096\n(+713)',
#   '32',
#   '620\n(+12)',
#   '104\n(+4)',
#   '695',
#   '179',
#   '528',
#   '30',
#   '347',
#   '1,037',
#   '641\n(+11)',
#   'N/A',
#   'N/A',
#   'N/A',
#   '58',
#   '783\n(+4)',
#   '545',
#   '186',
#   'N/A',
#   '5',
#   '330\n(+5)',
#   'N/A',
#   '92',
#   'N/A',
#   '117\n(-4)',
#   '48\n(+4)',
#   '220',
#   '759',
#   'N/A',
#   '51\n(+1)',
#   '20',
#   '131',
#   '42\n(+2)',
#   '647\n(+13)',
#   '681',
#   '38',
#   '197\n(+1)',
#   'N/A',
#   '201\n(+6)',
#   '13\n(+2)',
#   '192',
#   '59',
#   'N/A',
#   '226\n(-3)',
#   '205',
#   '90',
#   'N/A',
#   '7',
#   '2',
#   'N/A',
#   '58\n(+6)',
#   '62',
#   '20',
#   '176\n(-2)',
#   '17',
#   '38\n(+2)',
#   'N/A',
#   '11',
#   '15\n(+5)',
#   '21\n(-1)',
#   '73\n(+1)',
#   '23',
#   '1',
#   '23',
#   '131',
#   '44',
#   '1,124',
#   '60',
#   '8',
#   '12',
#   '37',
#   '5',
#   '2',
#   '127',
#   'N/A',
#   '344\n(+28)',
#   'N/A',
#   '152',
#   '1',
#   'N/A',
#   '23',
#   '11\n(-1)',
#   '10',
#   '2',
#   'N/A',
#   '22',
#   '3\n(-1)',
#   '67',
#   'N/A',
#   '18',
#   'N/A',
#   '23',
#   'N/A',
#   '10',
#   'N/A',
#   '10',
#   '11',
#   '7',
#   '1',
#   '3',
#   'N/A',
#   '1',
#   '14\n(-3)',
#   '23',
#   '16\n(+1)',
#   '8\n(-1)',
#   '7',
#   '46',
#   '10',
#   '7',
#   'N/A',
#   'N/A',
#   'N/A',
#   '5',
#   'N/A',
#   'N/A',
#   '4',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A',
#   '3',
#   '3',
#   'N/A',
#   'N/A',
#   'N/A',
#   '4',
#   'N/A',
#   '11',
#   'N/A',
#   '4',
#   '1',
#   'N/A',
#   '7\n(-3)',
#   '2',
#   'N/A',
#   '2',
#   '64',
#   '1',
#   '3',
#   '23',
#   'N/A',
#   '2\n(-1)',
#   '53',
#   '2',
#   '25',
#   'N/A',
#   'N/A',
#   'N/A',
#   '2',
#   'N/A',
#   '2',
#   '2',
#   '7',
#   'N/A',
#   '10',
#   '8',
#   'N/A',
#   '11',
#   '7',
#   'N/A',
#   '1',
#   '7',
#   'N/A',
#   'N/A',
#   '1',
#   '7',
#   'N/A',
#   'N/A',
#   'N/A',
#   '2',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['799,312\n(+174)',
#   '468,554\n(+621)',
#   '614,236\n(+236)',
#   '144,724\n(+131)',
#   '272,755\n(+1,224)',
#   '76,233\n(+192)',
#   '118,871\n(+34)',
#   '129,629\n(+80)',
#   '101,368\n(+132)',
#   '116,517\n(+12)',
#   '87,955',
#   '128,394\n(+51)',
#   '133,627\n(+90)',
#   '143,808\n(+1)',
#   '293,859\n(+245)',
#   '83,037\n(+51)',
#   '85,117\n(+400)',
#   '89,791\n(+8)',
#   '48,361\n(+156)',
#   '30,280\n(+40)',
#   '19,317\n(+45)',
#   '201,071\n(+84)',
#   '32,837\n(+93)',
#   '20,705\n(+30)',
#   '23,793\n(+21)',
#   '29,628\n(+10)',
#   '56,275\n(+106)',
#   '38,282',
#   '18,370',
#   '26,840',
#   '27,978\n(+3)',
#   '8,184\n(+2)',
#   '28,709\n(+5)',
#   '11,588\n(+51)',
#   '24,882\n(+190)',
#   '15,113',
#   '12,388\n(+39)',
#   '18,405\n(+12)',
#   '33,866',
#   '11,488\n(+2)',
#   '12,667\n(+16)',
#   '8,300\n(+1)',
#   '14,774\n(+1)',
#   '11,515',
#   '17,861\n(+82)',
#   '11,927\n(+56)',
#   '11,523\n(+2)',
#   '2,146\n(+1)',
#   '25,363\n(+1)',
#   '28,043\n(+47)',
#   '14,274\n(+46)',
#   '8,701\n(+8)',
#   '5,054\n(+13)',
#   '15,917\n(+19)',
#   '10,759\n(+115)',
#   '7,807\n(+18)',
#   '7,287',
#   '14,305\n(+27)',
#   '5,652',
#   '8,833\n(+1)',
#   '19,137',
#   '33,128',
#   '19,079\n(+12)',
#   '2,872\n(+9)',
#   '7,361\n(+1)',
#   '6,692\n(+20)',
#   '16,461\n(+2)',
#   '3,548\n(+56)',
#   '5,131\n(+7)',
#   '4,524',
#   '5,188\n(+23)',
#   '2,465',
#   '4,204\n(+2)',
#   '6,125\n(+1)',
#   '1,990\n(+5)',
#   '10,403',
#   '5,438\n(+8)',
#   '6,736\n(+9)',
#   '9,054\n(+32)',
#   '20,305\n(+68)',
#   '7,514\n(+29)',
#   '4,113',
#   '1,394',
#   '12,456',
#   '690\n(+6)',
#   '1,050',
#   '5,332',
#   '4,146\n(+16)',
#   '611',
#   '1,791\n(+2)',
#   '7,528\n(+17)',
#   '2,975',
#   '3,667',
#   '6,052\n(+6)',
#   '1,994\n(+4)',
#   '3,085\n(+8)',
#   '2,416',
#   '1,397\n(+2)',
#   '2,741\n(+4)',
#   '1,309',
#   '7,308',
#   '2,283\n(+2)',
#   '1,940',
#   '4,705\n(+1)',
#   '591',
#   '1,209',
#   '3,573\n(+1)',
#   '3,252',
#   '2,931\n(+4)',
#   '3,769\n(+5)',
#   '2,269',
#   '1,791',
#   '1,342\n(+1)',
#   '4,636',
#   '248',
#   '2,385\n(+9)',
#   '866',
#   '1,885',
#   '159\n(+12)',
#   '2,090\n(+29)',
#   '1,733',
#   '2,304',
#   '704',
#   '381',
#   '1,104',
#   '746',
#   '696',
#   '1,164\n(+2)',
#   '2,729',
#   '1,248',
#   '326',
#   '636',
#   '700',
#   '967',
#   '3,114',
#   '468',
#   '831\n(+2)',
#   '349',
#   '986\n(+1)',
#   '279\n(+3)',
#   '545\n(+3)',
#   '387',
#   '570',
#   '730',
#   '243',
#   '723',
#   '223',
#   '161',
#   '125',
#   '1,327',
#   '671',
#   '662',
#   '455',
#   '185',
#   '38',
#   '122',
#   '349',
#   '35',
#   '178',
#   '603\n(+1)',
#   '209',
#   '124',
#   '131',
#   '848',
#   '174',
#   '281\n(+16)',
#   '97',
#   '173',
#   '186',
#   '280',
#   '133',
#   '213',
#   '101',
#   '43\n(+1)',
#   '66',
#   '342',
#   '1,946\n(+1)',
#   '60',
#   '98',
#   '114',
#   '254',
#   '4',
#   '146',
#   '121',
#   '200',
#   '287',
#   '37',
#   '93',
#   '106',
#   '74',
#   '175',
#   '75',
#   '61',
#   '150',
#   '117',
#   '56',
#   '56',
#   '36',
#   '13',
#   '24',
#   '22',
#   '28',
#   '38',
#   '3',
#   '6',
#   '3',
#   '0',
#   '7',
#   '0',
#   '0',
#   '0',
#   '1',
#   '0',
#   '0',
#   '1',
#   '2',
#   '0',
#   '1',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'],
#  ['38,861,714\n(+21,031)',
#   '33,998,278\n(+9,481)',
#   '21,288,281\n(+5,477)',
#   '8,951,833\n(+39,409)',
#   '8,268,111\n(+30,646)',
#   '8,258,603\n(+25,103)',
#   '7,098,613\n(+8,513)',
#   '5,863,248\n(+10,182)',
#   '4,823,700\n(+20,600)',
#   '5,189,507\n(+1,349)',
#   '4,914,286',
#   '4,903,231\n(+2,629)',
#   '4,682,318\n(+6,451)',
#   '4,103,914\n(+275)',
#   '3,238,558\n(+2,040)',
#   '3,000,312\n(+22,204)',
#   '2,910,237\n(+10,270)',
#   '2,847,083\n(+1,476)',
#   '2,766,816\n(+896)',
#   '2,522,045\n(+5,352)',
#   'N/A',
#   'N/A',
#   '1,822,788\n(+12,989)',
#   '2,006,856\n(+6,354)',
#   '2,042,299\n(+1,321)',
#   '1,728,330\n(+804)',
#   '1,679,942\n(+4,758)',
#   '1,650,172',
#   '1,708,409\n(+133)',
#   '1,307,154',
#   '1,540,317\n(+299)',
#   '1,327,046',
#   '1,241,761\n(+172)',
#   '1,185,545\n(+4,553)',
#   '958,636\n(+1,712)',
#   'N/A',
#   '982,292\n(+14,107)',
#   '1,069,716\n(+2,543)',
#   '862,534',
#   '856,642\n(+1,798)',
#   '933,986\n(+879)',
#   '952,739\n(+231)',
#   '931,883\n(+171)',
#   '878,156',
#   '821,280\n(+7,099)',
#   '779,510\n(+5,052)',
#   '802,389\n(+342)',
#   '736,778\n(+79)',
#   '690,707\n(+136)',
#   '555,443\n(+1,147)',
#   '545,872\n(+5,804)',
#   '631,294\n(+655)',
#   '638,844\n(+2,191)',
#   '599,826\n(+507)',
#   '558,231\n(+9,131)',
#   '551,724\n(+2,391)',
#   '543,875',
#   '529,662\n(+422)',
#   '436,646\n(+2,551)',
#   '538,856\n(+32)',
#   '490,521',
#   '443,880',
#   '495,408\n(+660)',
#   '403,118',
#   '467,285\n(+213)',
#   '432,184\n(+277)',
#   '445,588\n(+102)',
#   '392,311\n(+2,170)',
#   '417,137\n(+904)',
#   '422,114',
#   '372,984\n(+2,345)',
#   '410,575\n(+29)',
#   '398,726\n(+853)',
#   '390,912\n(+193)',
#   '313,256',
#   '120,308',
#   '341,723\n(+2,720)',
#   '348,299\n(+211)',
#   '346,067\n(+841)',
#   '295,434\n(+531)',
#   '315,126\n(+1,106)',
#   '299,951',
#   '275,889\n(+24)',
#   '192,218',
#   '246,262\n(+1,897)',
#   '88,952',
#   '248,131\n(+46)',
#   '236,578\n(+737)',
#   '240,527\n(+128)',
#   '200,847\n(+682)',
#   '198,755\n(+336)',
#   '207,184\n(+70)',
#   '206,386\n(+15)',
#   '144,029\n(+127)',
#   '190,566\n(+772)',
#   '188,593\n(+548)',
#   '191,961',
#   '189,448\n(+189)',
#   '178,048\n(+179)',
#   '46,000',
#   '140,464\n(+13)',
#   '151,467\n(+412)',
#   '149,471',
#   '128,646\n(+19)',
#   '124,370',
#   '129,042',
#   '125,483\n(+18)',
#   '97,847\n(+418)',
#   '116,466\n(+20)',
#   '102,017\n(+925)',
#   '105,323',
#   '102,716',
#   '45,521',
#   '93,210\n(+47)',
#   '89,295\n(+105)',
#   '62,347\n(+90)',
#   '83,258',
#   '72,087\n(+3)',
#   '7,339',
#   '57,248\n(+306)',
#   '63,192\n(+9)',
#   '58,763',
#   '60,684\n(+20)',
#   '56,040',
#   '50,930',
#   '2,250',
#   '50,991',
#   '29,567\n(+1)',
#   '28,794',
#   '45,238',
#   '11,254',
#   '33,500',
#   '104',
#   '41,322',
#   '32,905',
#   '37,293\n(+43)',
#   '37,326\n(+64)',
#   '37,937\n(+6)',
#   '35,241\n(+19)',
#   '32,019\n(+383)',
#   '33,828\n(+327)',
#   '29,725',
#   '28,421',
#   '0',
#   '25,900\n(+5)',
#   '20,973',
#   '20,797\n(+628)',
#   '24,546',
#   '22,590',
#   '12,046',
#   '21,604',
#   '13,657',
#   '19,305\n(+149)',
#   '2,964',
#   '773',
#   '19,697\n(+1)',
#   '12,421',
#   '15,665',
#   '17,102\n(+16)',
#   '15,114\n(+29)',
#   '4,225',
#   '16,966',
#   '15,770',
#   '13,742',
#   '15,955\n(+22)',
#   '15,211\n(+202)',
#   '14,367',
#   '13,323',
#   '13,291',
#   '12,562\n(+9)',
#   '12,395',
#   '12,130\n(+2)',
#   '6,859',
#   '5,635\n(+68)',
#   '10,363',
#   '9,638',
#   '6,845\n(+16)',
#   '7,076\n(+28)',
#   '6,632\n(+144)',
#   '58',
#   '6,541\n(+6)',
#   '2,550',
#   '6,259\n(+1)',
#   '4,393',
#   '5,622',
#   '5,523',
#   '5,396',
#   '5,519',
#   '5,603',
#   '4,991',
#   '4,874',
#   '4,480\n(+2)',
#   '3,958',
#   '4,273',
#   '4,000',
#   '1,399',
#   '3,675',
#   '3,517\n(+15)',
#   '3,015',
#   '3,021',
#   '2,623\n(+30)',
#   '2,723',
#   'N/A',
#   '2,620',
#   'N/A',
#   '1,207',
#   '1,011',
#   '438',
#   'N/A',
#   '77',
#   '32',
#   '41',
#   '27',
#   '20',
#   '8',
#   '7',
#   '8',
#   '3',
#   '4',
#   '3',
#   '2',
#   '1',
#   '1'],
#  ['1.6',
#   '1.4',
#   '2.8',
#   '1.4',
#   '2.8',
#   '0.9',
#   '1.6',
#   '2.1',
#   '1.8',
#   '2.2',
#   '1.7',
#   '2.5',
#   '2.7',
#   '3.4',
#   '7.6',
#   '2.4',
#   '2.5',
#   '3.0',
#   '1.7',
#   '1.2',
#   '0.7',
#   '9.0',
#   '1.5',
#   '1.0',
#   '1.1',
#   '1.7',
#   '3.2',
#   '2.2',
#   '1.1',
#   '1.6',
#   '1.8',
#   '0.6',
#   '2.2',
#   '0.9',
#   '2.1',
#   '1.3',
#   '1.1',
#   '1.6',
#   '3.2',
#   '1.2',
#   '1.3',
#   '0.9',
#   '1.6',
#   '1.2',
#   '1.9',
#   '1.4',
#   '1.4',
#   '0.3',
#   '3.5',
#   '4.1',
#   '2.1',
#   '1.3',
#   '0.8',
#   '2.6',
#   '1.8',
#   '1.3',
#   '1.3',
#   '2.5',
#   '1.0',
#   '1.6',
#   '3.6',
#   '6.3',
#   '3.7',
#   '0.6',
#   '1.5',
#   '1.4',
#   '3.6',
#   '0.8',
#   '1.2',
#   '1.1',
#   '1.2',
#   '0.6',
#   '1.0',
#   '1.5',
#   '0.5',
#   '2.8',
#   '1.5',
#   '1.8',
#   '2.5',
#   '5.7',
#   '2.2',
#   '1.4',
#   '0.5',
#   '4.6',
#   '0.3',
#   '0.4',
#   '2.1',
#   '1.6',
#   '0.3',
#   '0.8',
#   '3.5',
#   '1.4',
#   '1.7',
#   '2.9',
#   '1.0',
#   '1.5',
#   '1.2',
#   '0.7',
#   '1.5',
#   '0.7',
#   '4.6',
#   '1.5',
#   '1.3',
#   '3.5',
#   '0.4',
#   '0.9',
#   '2.8',
#   '2.6',
#   '2.4',
#   '3.2',
#   '2.1',
#   '1.7',
#   '1.3',
#   '4.7',
#   '0.3',
#   '2.6',
#   '1.0',
#   '2.5',
#   '0.2',
#   '3.0',
#   '2.7',
#   '3.7',
#   '1.1',
#   '0.6',
#   '1.9',
#   '1.4',
#   '1.3',
#   '2.3',
#   '5.7',
#   '2.7',
#   '0.7',
#   '1.4',
#   '1.6',
#   '2.2',
#   '7.4',
#   '1.2',
#   '2.1',
#   '0.9',
#   '2.6',
#   '0.7',
#   '1.6',
#   '1.3',
#   '1.9',
#   '2.8',
#   '0.9',
#   '2.9',
#   '0.9',
#   '0.6',
#   '0.5',
#   '5.8',
#   '3.0',
#   '3.0',
#   '2.1',
#   '0.9',
#   '0.2',
#   '0.6',
#   '1.9',
#   '0.2',
#   '1.0',
#   '3.5',
#   '1.2',
#   '0.7',
#   '0.8',
#   '5.1',
#   '1.1',
#   '1.8',
#   '0.6',
#   '1.3',
#   '1.4',
#   '2.2',
#   '1.0',
#   '1.7',
#   '0.9',
#   '0.4',
#   '0.6',
#   '3.4',
#   '19.5',
#   '0.8',
#   '1.4',
#   '1.6',
#   '3.7',
#   '0.1',
#   '2.3',
#   '1.9',
#   '3.4',
#   '4.9',
#   '0.6',
#   '1.6',
#   '1.8',
#   '1.3',
#   '3.4',
#   '1.6',
#   '1.4',
#   '3.3',
#   '2.8',
#   '1.4',
#   '1.5',
#   '1.0',
#   '0.4',
#   '0.8',
#   '0.8',
#   '1.0',
#   '1.4',
#   '0.1',
#   '0.4',
#   '0.2',
#   '-',
#   '1.6',
#   '-',
#   '-',
#   '-',
#   '2.3',
#   '-',
#   '-',
#   '10',
#   '22.2',
#   '-',
#   '16.7',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-'],
#  ['79.2',
#   '98.3',
#   '96.4',
#   '88.5',
#   '86.4',
#   '94.7',
#   '93.5',
#   '96.0',
#   '83.8',
#   '97.4',
#   '95.8',
#   '96.8',
#   '93.7',
#   '96.4',
#   '83.4',
#   '85.5',
#   '85.0',
#   '96.2',
#   '97.7',
#   '96.3',
#   'N/A',
#   'N/A',
#   '85.9',
#   '95.3',
#   '98.2',
#   '96.9',
#   '94.5',
#   '93.9',
#   '98.9',
#   '76.8',
#   '97.7',
#   '98.9',
#   '96.7',
#   '94.8',
#   '79.2',
#   'N/A',
#   '85.9',
#   '93.9',
#   '80.7',
#   '87.2',
#   '96.3',
#   '99.0',
#   '98.1',
#   '93.5',
#   '89.2',
#   '92.9',
#   '97.7',
#   '99.3',
#   '96.3',
#   '80.7',
#   '81.7',
#   '94.7',
#   '98.0',
#   '97.1',
#   '92.5',
#   '94.2',
#   '96.0',
#   '94.2',
#   '78.0',
#   '98.0',
#   '91.7',
#   '84.6',
#   '95.0',
#   '84.2',
#   '97.9',
#   '92.4',
#   '96.3',
#   '89.0',
#   '97.0',
#   '98.3',
#   '89.4',
#   '99.3',
#   '98.1',
#   '97.9',
#   '82.2',
#   '31.8',
#   '92.0',
#   '93.8',
#   '95.5',
#   '83.0',
#   '93.3',
#   '98.5',
#   '99.4',
#   '70.5',
#   '94.1',
#   '34.3',
#   '97.3',
#   '93.7',
#   '98.9',
#   '90.7',
#   '92.6',
#   '96.8',
#   '98.2',
#   '68.6',
#   '91.6',
#   '94.7',
#   '98.5',
#   '98.2',
#   '97.2',
#   '25.2',
#   '89.3',
#   '96.7',
#   '98.7',
#   '96.0',
#   '94.6',
#   '98.6',
#   '97.1',
#   '76.8',
#   '97.0',
#   '85.8',
#   '98.0',
#   '96.2',
#   '45.4',
#   '94.5',
#   '97.8',
#   '68.4',
#   '94.5',
#   '97.4',
#   '10.3',
#   '82.2',
#   '97.0',
#   '94.9',
#   '98.3',
#   '94.9',
#   '87.6',
#   '4.1',
#   '97.1',
#   '58.3',
#   '60.3',
#   '97.2',
#   '24.5',
#   '73.5',
#   '0.2',
#   '93.8',
#   '78.2',
#   '95.1',
#   '95.4',
#   '98.9',
#   '93.5',
#   '85.8',
#   '96.6',
#   '96.6',
#   '94.2',
#   '-',
#   '98.7',
#   '83.8',
#   '83.4',
#   '98.8',
#   '97.4',
#   '52.3',
#   '95.0',
#   '62.8',
#   '91.1',
#   '14.2',
#   '3.8',
#   '99.4',
#   '65.9',
#   '89.8',
#   '98.3',
#   '87.4',
#   '24.6',
#   '99.2',
#   '94.4',
#   '82.8',
#   '97.8',
#   '96.8',
#   '95.8',
#   '98.1',
#   '98.4',
#   '96.9',
#   '97.5',
#   '97.6',
#   '58.6',
#   '50.0',
#   '93.5',
#   '96.5',
#   '68.5',
#   '96.9',
#   '92.4',
#   '0.8',
#   '94.0',
#   '37.8',
#   '97.2',
#   '68.6',
#   '95.5',
#   '94.9',
#   '92.7',
#   '95.3',
#   '97.8',
#   '90.7',
#   '95.5',
#   '97.9',
#   '87.8',
#   '95.2',
#   '96.6',
#   '35.4',
#   '98.5',
#   '94.3',
#   '88.5',
#   '97.6',
#   '91.4',
#   '98.0',
#   'N/A',
#   '99.2',
#   'N/A',
#   '90.5',
#   '75.9',
#   '98.4',
#   'N/A',
#   '100',
#   '54.2',
#   '93.2',
#   '100',
#   '100',
#   '80',
#   '77.8',
#   '100',
#   '50',
#   '100',
#   '100',
#   '100',
#   '100',
#   '100'],
#  ['148,270',
#   '25,052',
#   '103,862',
#   '148,932',
#   '65,580',
#   '103,444',
#   '116,255',
#   '72,731',
#   '68,743',
#   '117,833',
#   '109,743',
#   '99,506',
#   '82,612',
#   '15,560',
#   '30,115',
#   '92,685',
#   '78,247',
#   '49,884',
#   '25,842',
#   '80,936',
#   '151,713',
#   '67,717',
#   '198,250',
#   '30,184',
#   '51,703',
#   '47,277',
#   '92,368',
#   '92,037',
#   '13,659',
#   '146,824',
#   '9,568',
#   '155,032',
#   '5,814',
#   '143,109',
#   '12,434',
#   '118,706',
#   '126,941',
#   '112,066',
#   '110,647',
#   '113,499',
#   '51,665',
#   '84,952',
#   '25,728',
#   '92,059',
#   '88,331',
#   '210,229',
#   '28,173',
#   '75,014',
#   '60,681',
#   '99,105',
#   '122,345',
#   '97,689',
#   '68,983',
#   '34,467',
#   '146,961',
#   '57,774',
#   '111,218',
#   '26,260',
#   '113,422',
#   '15,790',
#   '45,842',
#   '29,725',
#   '9,579',
#   '82,685',
#   '110,622',
#   '171,877',
#   '64,901',
#   '8,600',
#   '15,123',
#   '84,160',
#   '200,764',
#   '96,771',
#   '37,474',
#   '114,914',
#   '116,202',
#   '38,153',
#   '54,076',
#   '3,229',
#   '89,819',
#   '3,477',
#   '114,041',
#   '59,632',
#   '163,115',
#   '83,149',
#   '44,721',
#   '47,812',
#   '4,741',
#   '133,821',
#   '84,390',
#   '167,013',
#   '103,042',
#   '1,038',
#   '11,431',
#   '4,788',
#   '8,157',
#   '69,198',
#   '82,883',
#   '5,761',
#   '28,087',
#   '32,899',
#   '4,039',
#   '249,350',
#   '4,848',
#   '9,012',
#   '108,884',
#   '4,213',
#   '50,840',
#   '2,786',
#   '7,183',
#   '18,334',
#   '59,381',
#   '4,023',
#   '7,746',
#   '69',
#   '168,996',
#   '30,772',
#   '140,753',
#   '4,419',
#   '9,830',
#   '49,790',
#   '1,982',
#   '3,235',
#   '2,339',
#   '65,952',
#   '649',
#   '137,825',
#   '58,558',
#   '86,495',
#   '2,729',
#   '40,105',
#   '153,555',
#   '162,363',
#   '118,098',
#   '1,592',
#   '959',
#   '88,857',
#   '8,412',
#   '68,991',
#   '47,940',
#   '16,758',
#   '3,915',
#   '2,342',
#   '75,862',
#   '440',
#   '3,170',
#   '2,195',
#   '86,726',
#   '2,050',
#   '235,869',
#   '1,448',
#   '57,811',
#   '10,155',
#   '16,663',
#   '76,748',
#   '1,714',
#   '15,034',
#   '3,414',
#   '51,125',
#   '105,976',
#   '854',
#   '2,589',
#   '1,792',
#   '216,295',
#   '696',
#   '152,783',
#   '752',
#   '34,269',
#   '9,679',
#   '13,668',
#   '70,632',
#   '1,136',
#   '1,658',
#   '2,424',
#   '2,335',
#   '130,361',
#   '4,133',
#   '335',
#   '2,060',
#   '213,084',
#   '25,135',
#   '287',
#   '102,523',
#   '3,272',
#   '802',
#   '52,327',
#   '1,151',
#   '80,835',
#   '170,640',
#   '92,007',
#   '49,576',
#   '311',
#   '106,703',
#   '118,207',
#   '5,162',
#   '42,286',
#   '102,131',
#   '17,024',
#   '95,000',
#   '69,746',
#   '79,965',
#   '109,408',
#   '52,238',
#   '91,462',
#   '3,421',
#   '162,094',
#   '88,916',
#   '23,463',
#   '-',
#   '22,701',
#   '119',
#   '10,183',
#   '8,814',
#   '33,708',
#   '29',
#   '17',
#   '-',
#   '442',
#   '20',
#   '68',
#   '15',
#   '329',
#   '9',
#   '9'],
#  ['331,002,651',
#   '1,380,004,385',
#   '212,559,417',
#   '67,886,011',
#   '145,934,462',
#   '84,339,067',
#   '65,273,511',
#   '83,992,949',
#   '83,783,942',
#   '45,195,774',
#   '46,754,778',
#   '50,882,891',
#   '60,461,826',
#   '273,523,615',
#   '128,932,753',
#   '37,846,611',
#   '43,733,762',
#   '59,308,690',
#   '109,581,078',
#   '32,365,999',
#   '17,134,872',
#   '32,971,854',
#   '10,708,981',
#   '69,799,978',
#   '40,222,493',
#   '37,742,154',
#   '19,237,691',
#   '19,116,201',
#   '126,476,461',
#   '11,589,623',
#   '164,689,383',
#   '8,655,535',
#   '220,892,340',
#   '8,737,371',
#   '97,338,579',
#   '10,099,265',
#   '9,006,398',
#   '10,196,709',
#   '9,660,351',
#   '8,654,622',
#   '18,776,707',
#   '11,326,616',
#   '36,910,560',
#   '10,203,134',
#   '10,423,054',
#   '3,989,167',
#   '29,136,808',
#   '9,890,402',
#   '11,818,619',
#   '6,948,445',
#   '5,459,642',
#   '6,825,445',
#   '9,449,323',
#   '17,915,568',
#   '4,105,267',
#   '10,139,177',
#   '5,094,118',
#   '21,413,249',
#   '4,937,786',
#   '34,813,871',
#   '11,673,021',
#   '17,643,054',
#   '54,409,800',
#   '5,792,202',
#   '4,314,767',
#   '2,722,289',
#   '7,132,538',
#   '51,269,185',
#   '28,435,940',
#   '5,101,414',
#   '2,078,938',
#   '4,270,571',
#   '10,847,910',
#   '3,473,730',
#   '3,278,290',
#   '9,904,607',
#   '6,871,292',
#   '114,963,588',
#   '4,033,963',
#   '102,334,404',
#   '2,963,243',
#   '5,106,626',
#   '1,701,575',
#   '3,280,819',
#   '5,850,342',
#   '5,421,241',
#   '53,771,296',
#   '1,886,198',
#   '2,881,053',
#   '1,326,535',
#   '2,083,374',
#   '206,139,589',
#   '18,383,955',
#   '43,851,044',
#   '25,499,884',
#   '2,877,797',
#   '2,351,627',
#   '33,469,203',
#   '6,524,195',
#   '5,540,720',
#   '38,928,346',
#   '628,066',
#   '31,255,435',
#   '14,862,924',
#   '1,207,359',
#   '31,072,940',
#   '2,540,905',
#   '45,741,007',
#   '16,718,965',
#   '6,486,205',
#   '1,810,463',
#   '26,545,863',
#   '12,952,218',
#   '1,439,323,776',
#   '540,544',
#   '2,961,167',
#   '625,978',
#   '16,743,927',
#   '7,275,560',
#   '1,399,488',
#   '32,866,272',
#   '19,129,952',
#   '26,378,274',
#   '895,312',
#   '89,561,403',
#   '400,124',
#   '896,445',
#   '586,632',
#   '17,500,658',
#   '1,160,164',
#   '298,682',
#   '280,908',
#   '375,265',
#   '27,691,018',
#   '43,849,260',
#   '441,543',
#   '4,649,658',
#   '555,987',
#   '786,552',
#   '2,225,734',
#   '8,947,024',
#   '13,132,795',
#   '397,628',
#   '59,734,218',
#   '8,278,724',
#   '11,402,528',
#   '287,375',
#   '12,123,200',
#   '98,347',
#   '15,893,222',
#   '393,244',
#   '2,142,249',
#   '1,271,768',
#   '272,815',
#   '11,890,784',
#   '1,318,445',
#   '5,518,087',
#   '341,243',
#   '164,093',
#   '20,250,833',
#   '6,624,554',
#   '9,537,645',
#   '77,265',
#   '23,816,775',
#   '106,766',
#   '20,903,273',
#   '437,479',
#   '1,402,985',
#   '988,000',
#   '183,627',
#   '11,193,725',
#   '7,496,981',
#   '4,829,767',
#   '4,822,233',
#   '85,033',
#   '2,416,668',
#   '29,825,964',
#   '3,546,421',
#   '33,691',
#   '285,498',
#   '24,206,644',
#   '65,722',
#   '1,968,001',
#   '7,976,983',
#   '112,523',
#   '5,057,681',
#   '71,986',
#   '33,931',
#   '62,278',
#   '110,940',
#   '16,425,864',
#   '42,876',
#   '38,128',
#   '869,601',
#   '97,929',
#   '38,666',
#   '219,159',
#   '39,242',
#   '48,863',
#   '38,717',
#   '26,223',
#   '53,199',
#   '30,231',
#   '771,608',
#   '9,877',
#   '15,003',
#   '56,770',
#   '-',
#   '3,480',
#   '649,335',
#   '5,794',
#   '4,992',
#   '801',
#   '686,884',
#   '597,339',
#   '-',
#   '18,094',
#   '307,145',
#   '59,190',
#   '198,414',
#   '6,077',
#   '115,023',
#   '105,695']]

# %%
print(len(all_data) )
# Out:
# 10

# %%
for i in range(len(all_data)):
    print(len( all_data[i]) )
# Out:
# 223
# 223
# 223
# 223
# 223
# 223
# 223
# 223
# 223
# 223

# %%
import pandas as pd

dict_dat = { "국가":all_data[0], 
             "확진자":all_data[1],
             "치료중":all_data[2], 
             "위중증":all_data[3],
             "사망자":all_data[4],
             "완치":all_data[5],
             "치명(%)":all_data[6],
             "완치(%)":all_data[7],
             "발생률":all_data[8],
             "인구수":all_data[9]
           }

dat = pd.DataFrame(dict_dat)
dat
# Out:
#            국가                    확진자                  치료중             위중증  \
# 0        미국🇺🇸  49,077,695\n(+26,778)  9,416,669\n(+5,573)  12,438\n(+130)
# 1        인도🇮🇳   34,572,523\n(+8,774)    105,691\n(-1,328)           8,944
# 2       브라질🇧🇷   22,076,863\n(+9,233)    174,346\n(+3,520)           8,318
# 3        영국🇬🇧  10,110,408\n(+39,567)     1,013,851\n(+27)             925
# 4       러시아🇷🇺   9,570,373\n(+33,548)  1,029,507\n(+1,678)           2,300
# ..        ...                    ...                  ...             ...
# 218   마셜 제도🇲🇭                      4                    0             N/A
# 219     사모아🇼🇸                      3                    0             N/A
# 220  세인트헬레나🇸🇭                      2                    0             N/A
# 221  미크로네시아🇫🇲                      1                    0             N/A
# 222      통가🇹🇴                      1                    0             N/A
#
#                    사망자                     완치 치명(%) 완치(%)      발생률  \
# 0      799,312\n(+174)  38,861,714\n(+21,031)   1.6  79.2  148,270
# 1      468,554\n(+621)   33,998,278\n(+9,481)   1.4  98.3   25,052
# 2      614,236\n(+236)   21,288,281\n(+5,477)   2.8  96.4  103,862
# 3      144,724\n(+131)   8,951,833\n(+39,409)   1.4  88.5  148,932
# 4    272,755\n(+1,224)   8,268,111\n(+30,646)   2.8  86.4   65,580
# ..                 ...                    ...   ...   ...      ...
# 218                  0                      4     -   100       68
# 219                  0                      3     -   100       15
# 220                  0                      2     -   100      329
# 221                  0                      1     -   100        9
# 222                  0                      1     -   100        9
#
#                인구수
# 0      331,002,651
# 1    1,380,004,385
# 2      212,559,417
# 3       67,886,011
# 4      145,934,462
# ..             ...
# 218         59,190
# 219        198,414
# 220          6,077
# 221        115,023
# 222        105,695
#
# [223 rows x 10 columns]

# %% [markdown]
# ### 주어진 데이터를 좀 더 사용하기 쉽게 전처리한다.

# %%
### 확진자를 총 확진자와, 일일 확진자로
dat['치료중합계'] = dat['치료중'].str.split('\n').str[0]
dat['치료중1일'] = dat['치료중'].str.split('\n').str[1]

dat['위중증합계'] = dat['위중증'].str.split('\n').str[0]
dat['위중증1일'] = dat['위중증'].str.split('\n').str[1]

dat['확진자합계'] = dat['확진자'].str.split('\n').str[0]
dat['확진자1일'] = dat['확진자'].str.split('\n').str[1]

dat['사망자합계'] = dat['사망자'].str.split('\n').str[0]
dat['사망자1일'] = dat['사망자'].str.split('\n').str[1]

dat['완치합계'] = dat['완치'].str.split('\n').str[0]
dat['완치1일'] = dat['완치'].str.split('\n').str[1]

dat = dat.drop( [ '치료중', '위중증', '확진자', '사망자', '완치'], axis=1)

dat.head()
# Out:
#       국가 치명(%) 완치(%)      발생률            인구수      치료중합계     치료중1일   위중증합계  \
# 0   미국🇺🇸   1.6  79.2  148,270    331,002,651  9,416,669  (+5,573)  12,438
# 1   인도🇮🇳   1.4  98.3   25,052  1,380,004,385    105,691  (-1,328)   8,944
# 2  브라질🇧🇷   2.8  96.4  103,862    212,559,417    174,346  (+3,520)   8,318
# 3   영국🇬🇧   1.4  88.5  148,932     67,886,011  1,013,851     (+27)     925
# 4  러시아🇷🇺   2.8  86.4   65,580    145,934,462  1,029,507  (+1,678)   2,300
#
#     위중증1일       확진자합계      확진자1일    사망자합계     사망자1일        완치합계       완치1일
# 0  (+130)  49,077,695  (+26,778)  799,312    (+174)  38,861,714  (+21,031)
# 1     NaN  34,572,523   (+8,774)  468,554    (+621)  33,998,278   (+9,481)
# 2     NaN  22,076,863   (+9,233)  614,236    (+236)  21,288,281   (+5,477)
# 3     NaN  10,110,408  (+39,567)  144,724    (+131)   8,951,833  (+39,409)
# 4     NaN   9,570,373  (+33,548)  272,755  (+1,224)   8,268,111  (+30,646)

# %%
dat['발생률'] = dat['발생률'].str.replace(pat=r'[,]', repl=r'', regex=True)
dat['인구수'] = dat['인구수'].str.replace(pat=r'[,]', repl=r'', regex=True)


dat['치료중합계'] = dat['치료중합계'].str.replace(pat=r'[,]', repl=r'', regex=True)
dat['치료중1일'] = dat['치료중1일'].str.replace(pat=r'[,()]', repl=r'', regex=True)

dat['위중증합계'] = dat['위중증합계'].str.replace(pat=r'[,]', repl=r'', regex=True)
dat['위중증1일'] = dat['확진자1일'].str.replace(pat=r'[,()]', repl=r'', regex=True)

dat['확진자합계'] = dat['확진자합계'].str.replace(pat=r'[,]', repl=r'', regex=True)
dat['확진자1일'] = dat['확진자1일'].str.replace(pat=r'[,()]', repl=r'', regex=True)

dat['사망자합계'] = dat['사망자합계'].str.replace(pat=r'[,]', repl=r'', regex=True)
dat['사망자1일'] = dat['사망자1일'].str.replace(pat=r'[,()]', repl=r'', regex=True)

dat['완치합계'] = dat['완치합계'].str.replace(pat=r'[,]', repl=r'', regex=True)
dat['완치1일'] = dat['완치1일'].str.replace(pat=r'[,()]', repl=r'', regex=True)
dat.head()
# Out:
#       국가 치명(%) 완치(%)     발생률         인구수    치료중합계  치료중1일  위중증합계   위중증1일  \
# 0   미국🇺🇸   1.6  79.2  148270   331002651  9416669  +5573  12438  +26778
# 1   인도🇮🇳   1.4  98.3   25052  1380004385   105691  -1328   8944   +8774
# 2  브라질🇧🇷   2.8  96.4  103862   212559417   174346  +3520   8318   +9233
# 3   영국🇬🇧   1.4  88.5  148932    67886011  1013851    +27    925  +39567
# 4  러시아🇷🇺   2.8  86.4   65580   145934462  1029507  +1678   2300  +33548
#
#       확진자합계   확진자1일   사망자합계  사망자1일      완치합계    완치1일
# 0  49077695  +26778  799312   +174  38861714  +21031
# 1  34572523   +8774  468554   +621  33998278   +9481
# 2  22076863   +9233  614236   +236  21288281   +5477
# 3  10110408  +39567  144724   +131   8951833  +39409
# 4   9570373  +33548  272755  +1224   8268111  +30646

# %%
from datetime import datetime
from datetime import date
import datetime
import os

today = datetime.date.today()
yesterday = today - datetime.timedelta(days=1)

# print(today)
# print(yesterday)
if flag_today == True:
    file_make_time = today
else:
    file_make_time = yesterday

print( file_make_time )

print( os.getcwd() )
path_dir = os.getcwd() + "\\data\\"
path_file = path_dir + str(file_make_time)
print( path_dir,  path_file, sep="\n" )
# Out:
# 2021-11-28
# C:\Users\toto\Documents\Github\corona_analysis
# C:\Users\toto\Documents\Github\corona_analysis\data\
# C:\Users\toto\Documents\Github\corona_analysis\data\2021-11-28

# %%
dat.to_csv(path_file + "_corona.csv", index=False)
dat.to_excel(path_file + "_corona.xlsx", index=False)
os.listdir( path_dir )
# Out:
# ['2021-08-07_corona.csv',
#  '2021-08-07_corona.xlsx',
#  '2021-09-19_corona.csv',
#  '2021-09-19_corona.xlsx',
#  '2021-09-20_corona.csv',
#  '2021-09-20_corona.xlsx',
#  '2021-09-28_corona.csv',
#  '2021-09-28_corona.xlsx',
#  '2021-09-29_corona.csv',
#  '2021-09-29_corona.xlsx',
#  '2021-11-28_corona.csv',
#  '2021-11-28_corona.xlsx',
#  '20210808_16datamerge.csv',
#  '20210808_16datamerge.xlsx',
#  '20210808_16_today_corona.csv',
#  '20210808_16_today_corona.xlsx',
#  '20210808_16_vaccine_bloomberg.csv',
#  '20210808_16_vaccine_bloomberg.xlsx',
#  '20210920_00_vaccine_bloomberg.csv',
#  '20210920_00_vaccine_bloomberg.xlsx',
#  '20210921_00_datamerge.csv',
#  '20210921_00_datamerge.xlsx',
#  '20210929_00_vaccine_bloomberg.csv',
#  '20210929_00_vaccine_bloomberg.xlsx',
#  '20210929_01_datamerge.csv',
#  '20210929_01_datamerge.xlsx',
#  '20210929_14_vaccine_bloomberg.csv',
#  '20210929_14_vaccine_bloomberg.xlsx',
#  '20210930_00_datamerge.csv',
#  '20210930_00_datamerge.xlsx',
#  '20210930_00_vaccine_bloomberg.csv',
#  '20210930_00_vaccine_bloomberg.xlsx',
#  'country.csv',
#  'country.xlsx']

# %% [markdown]
# ### 추가 과제
#  * 위증증 - 총 합계와 일일 합계 나누기
#  * 확진자/총인구 값 구하기

# %% [markdown]
# * history
#  * 2021.09.30  version 1.xx
# * 출처를 밝히시고 위의 내용에 대해 자유롭게 사용 가능합니다.
