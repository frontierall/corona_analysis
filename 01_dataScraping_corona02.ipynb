# %% [markdown]
# ### 코로나 데이터 웹 데이터 수집

# %% [markdown]
# ### 학습내용
# * 추가적인 내용을 수집한다.(인구수, 위중증 추가)
# * 금일 정보가 아닌 어제기준 완료된 데이터를 가져와 본다.

# %% [markdown]
# * 코로나 19(COVID-19) 실시간 상황판
# * url : https://coronaboard.kr/

# %%
from IPython.display import display, Image
import os, warnings
import re
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ### 01 웹 브라우저 띄우기

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

# %%
driver = webdriver.Chrome('./chromedriver/chromedriver_91')

## https://www.amazon.com/
url = 'https://coronaboard.kr/'
driver.get(url)

import time
time.sleep(3)  # 홈페이지 로딩 시간 3초

# %% [markdown]
# ### 02 더보기 버튼 찾기

# %%
from selenium.webdriver import ActionChains

some_tag = driver.find_element_by_id('show-more')
ActionChains(driver).move_to_element(some_tag).perform()
some_tag.click()

# %%
some_tag = driver.find_element_by_id('show-more')
ActionChains(driver).move_to_element(some_tag).perform()
some_tag.click()

# %% [markdown]
# ### 03 추가정보선택
#  * 콤보박스 : //*[@id="global-slide"]/div/div[2]/div/div/button/div/div/div

# %%
some_tag = driver.find_element_by_xpath('//*[@id="global-slide"]/div/div[2]/div/div/button/div/div/div')
ActionChains(driver).move_to_element(some_tag).perform()
some_tag.click()

# %% [markdown]
# * //*[@id="bs-select-1-5"]

# %% [markdown]
# ### 인구수 추가

# %%
sel_menu = driver.find_element_by_xpath('//*[@id="bs-select-1-5"]')
sel_menu.click()

# %% [markdown]
# ### 위중증 추가

# %%
sel_menu = driver.find_element_by_xpath('//*[@id="bs-select-1-1"]')
sel_menu.click()

# %%
some_tag.click()

# %% [markdown]
# ### 국가 정보 가져오기

# %% [markdown]
# * //*[@id="country-table"]/div/div/table/tbody/tr[1]/td[2]/a
# * //*[@id="country-table"]/div/div/table/tbody/tr[2]/td[2]/a
# * //*[@id="country-table"]/div/div/table/tbody/tr[4]/td[2]/a

# %%
sel_country = driver.find_elements_by_xpath('//*[@id="country-table"]/div/div/table/tbody/tr/td[2]')
len(sel_country)
# Out:
# 221

# %%
for one in sel_country:
    print(one.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-c1721e5200ab> in <module>
# ----> 1 for one in sel_country:
#       2     print(one.text)
#
# NameError: name 'sel_country' is not defined

# %% [markdown]
# ### 확진자 정보
#  * //*[@id="country-table"]/div/div/table/tbody/tr[1]/td[3]
#  * //*[@id="country-table"]/div/div/table/tbody/tr[2]/td[3]
#  * ..
#  * //*[@id="country-table"]/div/div/table/tbody/tr[5]/td[3]
#
# ### 위중증
#  * //*[@id="country-table"]/div/div/table/tbody/tr[1]/td[4]
#  * //*[@id="country-table"]/div/div/table/tbody/tr[3]/td[4]
#  * ..
#
# ### 사망자 정보
#  * //*[@id="country-table"]/div/div/table/tbody/tr[1]/td[5]
#  * //*[@id="country-table"]/div/div/table/tbody/tr[2]/td[5]
#  * ...
#
# ### 완치
#  * //*[@id="country-table"]/div/div/table/tbody/tr[1]/td[6]
#  * //*[@id="country-table"]/div/div/table/tbody/tr[2]/td[6]
#  * ..
#
# ### 치명(%)
#  * //*[@id="country-table"]/div/div/table/tbody/tr[1]/td[7]
#  * //*[@id="country-table"]/div/div/table/tbody/tr[2]/td[7]
#  * ...
#
# ### 완치(%)
#  * //*[@id="country-table"]/div/div/table/tbody/tr[2]/td[8]
#
#
# ### 발생률
#  * //*[@id="country-table"]/div/div/table/tbody/tr[1]/td[9]
#  * //*[@id="country-table"]/div/div/table/tbody/tr[2]/td[9]
#  * ...
#
# ### 인구수
#  * //*[@id="country-table"]/div/div/table/tbody/tr[1]/td[10]
#  * //*[@id="country-table"]/div/div/table/tbody/tr[2]/td[10]
#  * ...

# %% [markdown]
# ### 어제 오늘 선택

# %%
# 어제 : //*[@id="global-slide"]/div/div[2]/ul/li[2]/a
flag_today = False # False : 어제, Today : 오늘

# %%
if flag_today==False:
    sel_yesterday = driver.find_element_by_xpath('//*[@id="global-slide"]/div/div[2]/ul/li[2]/a')
    sel_yesterday.click()

# %%
all_data = []
for i in range(2, 11):
    tmp = '//*[@id="country-table"]/div/div/table/tbody/tr/td[{}]'.format(i)
    # print(tmp)
    sel_ele = driver.find_elements_by_xpath(tmp)
    
    
    column_data = []
    for one in sel_ele:
        # print(one.text)
        column_data.append(one.text)
    
    print( len(sel_ele) )
    all_data.append(column_data)
    print(column_data)
    print()
    
all_data
# Out:
# 221
# ['미국🇺🇸', '인도🇮🇳', '브라질🇧🇷', '러시아🇷🇺', '프랑스🇫🇷', '영국🇬🇧', '터키🇹🇷', '아르헨티나🇦🇷', '콜롬비아🇨🇴', '스페인🇪🇸', '이탈리아🇮🇹', '이란🇮🇷', '독일🇩🇪', '인도네시아🇮🇩', '멕시코🇲🇽', '폴란드🇵🇱', '남아프리카 공화국🇿🇦', '우크라이나🇺🇦', '페루🇵🇪', '네덜란드🇳🇱', '이라크🇮🇶', '체코🇨🇿', '필리핀🇵🇭', '칠레🇨🇱', '캐나다🇨🇦', '방글라데시🇧🇩', '말레이시아🇲🇾', '벨기에🇧🇪', '스웨덴🇸🇪', '루마니아🇷🇴', '파키스탄🇵🇰', '일본🇯🇵*', '포르투갈🇵🇹', '이스라엘🇮🇱', '헝가리🇭🇺', '요르단🇯🇴', '태국🇹🇭', '세르비아🇷🇸', '스위스🇨🇭', '네팔🇳🇵', '아랍에미레이트🇦🇪', '모로코🇲🇦', '오스트리아🇦🇹', '카자흐스탄🇰🇿', '튀니지🇹🇳', '레바논🇱🇧', '사우디아라비아🇸🇦', '그리스🇬🇷', '에콰도르🇪🇨', '볼리비아🇧🇴', '파라과이🇵🇾', '벨라루스🇧🇾', '조지아🇬🇪', '파나마🇵🇦', '쿠바🇨🇺', '불가리아🇧🇬', '코스타리카🇨🇷', '쿠웨이트🇰🇼', '슬로바키아🇸🇰', '과테말라🇬🇹', '우루과이🇺🇾', '크로아티아🇭🇷', '아제르바이잔🇦🇿', '도미니카 공화국🇩🇴', '스리랑카🇱🇰', '덴마크🇩🇰', '미얀마🇲🇲', '팔레스타인🇵🇸', '베네수엘라🇻🇪', '아일랜드🇮🇪', '온두라스🇭🇳', '오만🇴🇲', '리투아니아🇱🇹', '이집트🇪🇬', '에티오피아🇪🇹', '바레인🇧🇭', '리비아🇱🇾', '몰도바🇲🇩', '슬로베니아🇸🇮', '아르메니아🇦🇲', '카타르🇶🇦', '케냐🇰🇪', '대한민국🇰🇷', '보스니아 헤르체고비나🇧🇦', '잠비아🇿🇲', '베트남🇻🇳', '알제리🇩🇿', '나이지리아🇳🇬', '몽골🇲🇳', '키르기스스탄🇰🇬', '북마케도니아🇲🇰', '아프가니스탄🇦🇫', '노르웨이🇳🇴', '라트비아🇱🇻', '우즈베키스탄🇺🇿', '에스토니아🇪🇪', '알바니아🇦🇱', '모잠비크🇲🇿', '보츠와나🇧🇼', '나미비아🇳🇦', '짐바브웨🇿🇼', '핀란드🇫🇮', '코소보🇽🇰', '가나🇬🇭', '키프로스🇨🇾', '몬테네그로🇲🇪', '우간다🇺🇬', '중국🇨🇳', '엘살바도르🇸🇻', '카메룬🇨🇲', '캄보디아🇰🇭', '몰디브🇲🇻', '르완다🇷🇼', '룩셈부르크🇱🇺', '세네갈🇸🇳', '싱가포르🇸🇬', '말라위🇲🇼', '자메이카🇯🇲', '콩고민주공화국🇨🇩', '코트디부아르🇨🇮', '앙골라🇦🇴', '마다가스카르🇲🇬', '레위니옹🇷🇪', '트리니다드 토바고🇹🇹', '수단🇸🇩', '피지🇫🇯', '호주🇦🇺', '몰타 공화국🇲🇹', '카보베르데🇨🇻', '프랑스령 기아나🇬🇫', '에스와티니🇸🇿', '모리타니🇲🇷', '기니🇬🇳', '시리아🇸🇾', '수리남🇸🇷', '가봉🇬🇦', '과들루프🇬🇵', '마르티니크🇲🇶', '가이아나🇬🇾', '프랑스령 폴리네시아🇵🇫', '아이티🇭🇹', '마요트🇾🇹', '세이셸🇸🇨', '파푸아뉴기니🇵🇬', '토고🇹🇬', '대만🇹🇼', '소말리아🇸🇴', '타지키스탄🇹🇯', '바하마🇧🇸', '안도라🇦🇩', '말리🇲🇱', '벨리즈🇧🇿', '퀴라소🇨🇼', '부르키나파소🇧🇫', '레소토🇱🇸', '콩고공화국🇨🇬', '아루바🇦🇼', '홍콩🇭🇰', '지부티🇩🇯', '동티모르🇹🇱', '남수단🇸🇸', '니카라과🇳🇮', '적도 기니🇬🇶', '아이슬란드🇮🇸', '베냉🇧🇯', '감비아🇬🇲', '라오스🇱🇦', '부룬디🇧🇮', '중앙아프리카 공화국🇨🇫', '예멘🇾🇪', '에리트레아🇪🇷', '시에라리온🇸🇱', '세인트루시아🇱🇨', '니제르🇳🇪', '라이베리아🇱🇷', '맨섬🇮🇲', '산마리노🇸🇲', '지브롤터🇬🇮', '차드🇹🇩', '기니비사우🇬🇼', '모리셔스🇲🇺', '바베이도스🇧🇧', '코모로🇰🇲', '리히텐슈타인🇱🇮', '모나코🇲🇨', '신트마르턴🇸🇽', '뉴질랜드🇳🇿', '세인트마틴 섬🇲🇫', '버뮤다🇧🇲', '부탄🇧🇹', '터크스 케이커스 제도🇹🇨', '영국령 버진아일랜드🇻🇬', '상투메 프린시페🇸🇹', '세인트빈센트 그레나딘🇻🇨', '카리브 네덜란드🇧🇶', '생바르텔레미🇧🇱', '앤티가 바부다🇦🇬', '탄자니아🇹🇿', '페로 제도🇫🇴', '케이맨 제도🇰🇾', '세인트키츠 네비스🇰🇳', '왈리스 퓌티나🇼🇫', '브루나이🇧🇳', '도미니카 연방🇩🇲', '그린란드🇬🇱', '그레나다🇬🇩', '뉴칼레도니아🇳🇨', '앵귈라🇦🇮', '포클랜드 제도🇫🇰', '마카오🇲🇴', '생피에르 미클롱🇵🇲', '바티칸 시국🇻🇦', '몬트세랫🇲🇸', '솔로몬 제도🇸🇧', '서사하라🇪🇭', '잔담(크루즈)🚢', '마셜 제도🇲🇭', '바누아투🇻🇺', '사모아🇼🇸', '세인트헬레나🇸🇭', '미크로네시아🇫🇲']
#
# 221
# ['36,449,535\n(+144,461)', '31,902,422\n(+40,647)', '20,108,746\n(+42,159)', '6,424,884\n(+22,320)', '6,258,953\n(+25,077)', '6,014,023\n(+31,442)', '5,870,741\n(+23,957)', '5,002,951\n(+13,549)', '4,828,583\n(+6,980)', '4,588,132\n(+21,561)', '4,383,787\n(+6,599)', '4,119,110\n(+26,439)', '3,793,341\n(+2,826)', '3,639,616\n(+31,753)', '2,944,226\n(+21,563)', '2,883,976\n(+180)', '2,511,178\n(+13,
)', '12,824\n(+42)', '14,444\n(+28)', '13,982\n(+5)', '13,622\n(+33)', '13,297\n(+81)', '13,391\n(+6)', '6,664', '12,421', '11,397\n(+138)', '11,724\n(+3)', '11,495', '10,114\n(+19)', '10,514', '4,225', '8,730', '7,254\n(+92)', '8,136', '7,536\n(+113)', '3,946\n(+59)', '773', '6,859', '4,305\n(+34)', '6,487\n(+3)', '4,299\n(+6)', '5,416\n(+12)', '5,359\n(+5)', '2,715', '4,321\n(+302)', '5,009', '4,771\n(+102)', '4,796', '4,099\n(+43)', '1,854', '4,310\n(+59)', '3,875\n(+2)', '3,022', '2,790\n(+20)', '2,703\n(+13)', '2,824', '1,399', '2,510\n(+7)', '2,460', '2,439\n(+1)', '1,914', '2,368\n(+3)', '2,233', '1,673', '462', '1,246\n(+2)', '183', '963', '639\n(+4)', '558\n(+9)', '438', '289', '209', '101\n(+11)', '161', '58', '111', '63', '57\n(+1)', '26', '27', '20', '20', '8', '7', '4', '3', '3', '2', '1']
#
# 221
# ['1.7', '1.3', '2.8', '2.6', '1.8', '2.2', '0.9', '2.1', '2.5', '1.8', '2.9', '2.3', '2.4', '2.9', '8.3', '2.6', '3.0', '2.4', '9.3', '0.9', '1.1', '1.8', '1.7', '2.2', '1.9', '1.7', '0.8', '2.2', '1.3', '3.2', '2.2', '1.5', '1.8', '0.7', '3.7', '1.3', '0.8', '1.0', '1.5', '1.4', '0.3', '1.5', '1.6', '1.1', '3.4', '1.4', '1.6', '2.6', '6.5', '3.8', '3.4', '0.8', '1.4', '1.6', '0.7', '4.3', '1.2', '0.6', '3.2', '2.8', '1.6', '2.3', '1.4', '1.2', '1.5', '0.8', '3.5', '1.1', '1.2', '1.6', '2.7', '1.3', '1.5', '5.8', '1.6', '0.5', '1.4', '2.4', '1.7', '2.0', '0.3', '2.0', '1.0', '4.7', '1.7', '1.5', '2.5', '1.2', '0.5', '1.4', '3.5', '4.6', '0.6', '1.8', '0.7', '0.9', '1.8', '1.2', '1.4', '2.6', '3.3', '0.9', '2.1', '0.8', '0.4', '1.6', '2.9', '5.0', '3.0', '1.6', '1.9', '0.3', '1.2', '1.1', '2.2', '0.1', '3.2', '2.2', '2.0', '0.7', '2.4', '2.2', '0.7', '2.8', '7.5', '0.8', '2.6', '1.2', '0.9', '0.6', '2.7', '2.1', '0.9', '7.4', '2.5', '0.6', '1.0', '0.6', '2.4', '0.7', '2.8', '0.9', '0.5', '1.1', '0.9', '5.1', '5.3', '0.8', '1.9', '0.9', '3.6', '2.3', '0.9', '1.2', '2.8', '1.3', '0.9', '1.8', '1.3', '0.2', '1.1', '2.0', '1.4', '0.3', '1.3', '2.8', '0.1', '0.5', '1.4', '19.4', '0.5', '1.9', '1.6', '3.5', '2.7', '0.6', '1.7', '1.9', '3.5', '1.7', '0.4', '1.1', '3.6', '1.9', '1.1', '1.2', '0.9', '1.4', '1.3', '0.1', '0.7', '1.2', '1.5', '0.5', '1.0', '0.1', '3.2', '2.1', '0.2', '0.3', '0.5', '1.6', '0.9', '-', '-', '0.6', '-', '-', '-', '-', '-', '-', '4.5', '-', '10', '22.2', '-', '25', '-', '-', '-']
2,225,734', '400,124', '375,265', '786,552', '280,908', '11,402,528', '272,815', '98,347', '8,947,024', '8,278,724', '23,816,775', '15,893,222', '9,537,645', '393,244', '77,265', '20,250,833', '397,628', '164,093', '20,903,273', '2,142,249', '5,518,087', '106,766', '7,496,981', '988,000', '1,318,445', '11,193,725', '6,624,554', '1,402,985', '341,243', '12,123,200', '2,416,668', '7,275,560', '11,890,784', '4,829,767', '29,825,964', '3,546,421', '7,976,983', '183,627', '24,206,644', '5,057,681', '85,033', '33,931', '33,691', '16,425,864', '1,968,001', '1,271,768', '287,375', '869,601', '38,128', '39,242', '42,876', '4,822,233', '38,666', '62,278', '771,608', '38,717', '30,231', '219,159', '110,940', '26,223', '9,877', '97,929', '59,734,218', '48,863', '65,722', '53,199', '-', '437,479', '71,986', '56,770', '112,523', '285,498', '15,003', '3,480', '649,335', '5,794', '801', '4,992', '686,884', '597,339', '-', '59,190', '307,145', '198,414', '6,077', '115,023']
# [['미국🇺🇸',
#   '인도🇮🇳',
#   '브라질🇧🇷',
#   '러시아🇷🇺',
#   '프랑스🇫🇷',
#   '영국🇬🇧',
#   '터키🇹🇷',
#   '아르헨티나🇦🇷',
#   '콜롬비아🇨🇴',
#   '스페인🇪🇸',
#   '이탈리아🇮🇹',
#   '이란🇮🇷',
#   '독일🇩🇪',
#   '인도네시아🇮🇩',
#   '멕시코🇲🇽',
#   '폴란드🇵🇱',
#   '남아프리카 공화국🇿🇦',
#   '우크라이나🇺🇦',
#   '페루🇵🇪',
#   '네덜란드🇳🇱',
#   '이라크🇮🇶',
#   '체코🇨🇿',
#   '필리핀🇵🇭',
#   '칠레🇨🇱',
#   '캐나다🇨🇦',
#   '방글라데시🇧🇩',
#   '말레이시아🇲🇾',
#   '벨기에🇧🇪',
#   '스웨덴🇸🇪',
#   '루마니아🇷🇴',
#   '파키스탄🇵🇰',
#   '일본🇯🇵*',
#   '포르투갈🇵🇹',
#   '이스라엘🇮🇱',
#   '헝가리🇭🇺',
#   '요르단🇯🇴',
#   '태국🇹🇭',
#   '세르비아🇷🇸',
#   '스위스🇨🇭',
#   '네팔🇳🇵',
#   '아랍에미레이트🇦🇪',
#   '모로코🇲🇦',
#   '오스트리아🇦🇹',
#   '카자흐스탄🇰🇿',
#   '튀니지🇹🇳',
#   '레바논🇱🇧',
#   '사우디아라비아🇸🇦',
#   '그리스🇬🇷',
#   '에콰도르🇪🇨',
#   '볼리비아🇧🇴',
#   '파라과이🇵🇾',
#   '벨라루스🇧🇾',
#   '조지아🇬🇪',
#   '파나마🇵🇦',
#   '쿠바🇨🇺',
#   '불가리아🇧🇬',
#   '코스타리카🇨🇷',
#   '쿠웨이트🇰🇼',
#   '슬로바키아🇸🇰',
#   '과테말라🇬🇹',
#   '우루과이🇺🇾',
#   '크로아티아🇭🇷',
#   '아제르바이잔🇦🇿',
#   '도미니카 공화국🇩🇴',
#   '스리랑카🇱🇰',
#   '덴마크🇩🇰',
#   '미얀마🇲🇲',
#   '팔레스타인🇵🇸',
#   '베네수엘라🇻🇪',
#   '아일랜드🇮🇪',
#   '온두라스🇭🇳',
#   '오만🇴🇲',
#   '리투아니아🇱🇹',
#   '이집트🇪🇬',
#   '에티오피아🇪🇹',
#   '바레인🇧🇭',
#   '리비아🇱🇾',
#   '몰도바🇲🇩',
#   '슬로베니아🇸🇮',
#   '아르메니아🇦🇲',
#   '카타르🇶🇦',
#   '케냐🇰🇪',
#   '대한민국🇰🇷',
#   '보스니아 헤르체고비나🇧🇦',
#   '잠비아🇿🇲',
#   '베트남🇻🇳',
#   '알제리🇩🇿',
#   '나이지리아🇳🇬',
#   '몽골🇲🇳',
#   '키르기스스탄🇰🇬',
#   '북마케도니아🇲🇰',
#   '아프가니스탄🇦🇫',
#   '노르웨이🇳🇴',
#   '라트비아🇱🇻',
#   '우즈베키스탄🇺🇿',
#   '에스토니아🇪🇪',
#   '알바니아🇦🇱',
#   '모잠비크🇲🇿',
#   '보츠와나🇧🇼',
#   '나미비아🇳🇦',
#   '짐바브웨🇿🇼',
#   '핀란드🇫🇮',
#   '코소보🇽🇰',
#   '가나🇬🇭',
#   '키프로스🇨🇾',
#   '몬테네그로🇲🇪',
#   '우간다🇺🇬',
#   '중국🇨🇳',
#   '엘살바도르🇸🇻',
#   '카메룬🇨🇲',
#   '캄보디아🇰🇭',
#   '몰디브🇲🇻',
#   '르완다🇷🇼',
#   '룩셈부르크🇱🇺',
#   '세네갈🇸🇳',
#   '싱가포르🇸🇬',
#   '말라위🇲🇼',
#   '자메이카🇯🇲',
#   '콩고민주공화국🇨🇩',
#   '코트디부아르🇨🇮',
#   '앙골라🇦🇴',
#   '마다가스카르🇲🇬',
#   '레위니옹🇷🇪',
#   '트리니다드 토바고🇹🇹',
#   '수단🇸🇩',
#   '피지🇫🇯',
#   '호주🇦🇺',
#   '몰타 공화국🇲🇹',
#   '카보베르데🇨🇻',
#   '프랑스령 기아나🇬🇫',
#   '에스와티니🇸🇿',
#   '모리타니🇲🇷',
#   '기니🇬🇳',
#   '시리아🇸🇾',
#   '수리남🇸🇷',
#   '가봉🇬🇦',
#   '과들루프🇬🇵',
#   '마르티니크🇲🇶',
#   '가이아나🇬🇾',
#   '프랑스령 폴리네시아🇵🇫',
#   '아이티🇭🇹',
#   '마요트🇾🇹',
#   '세이셸🇸🇨',
#   '파푸아뉴기니🇵🇬',
#   '토고🇹🇬',
#   '대만🇹🇼',
#   '소말리아🇸🇴',
#   '타지키스탄🇹🇯',
#   '바하마🇧🇸',
#   '안도라🇦🇩',
#   '말리🇲🇱',
#   '벨리즈🇧🇿',
#   '퀴라소🇨🇼',
#   '부르키나파소🇧🇫',
#   '레소토🇱🇸',
#   '콩고공화국🇨🇬',
#   '아루바🇦🇼',
#   '홍콩🇭🇰',
#   '지부티🇩🇯',
#   '동티모르🇹🇱',
#   '남수단🇸🇸',
#   '니카라과🇳🇮',
#   '적도 기니🇬🇶',
#   '아이슬란드🇮🇸',
#   '베냉🇧🇯',
#   '감비아🇬🇲',
#   '라오스🇱🇦',
#   '부룬디🇧🇮',
#   '중앙아프리카 공화국🇨🇫',
#   '예멘🇾🇪',
#   '에리트레아🇪🇷',
#   '시에라리온🇸🇱',
#   '세인트루시아🇱🇨',
#   '니제르🇳🇪',
#   '라이베리아🇱🇷',
#   '맨섬🇮🇲',
#   '산마리노🇸🇲',
#   '지브롤터🇬🇮',
#   '차드🇹🇩',
#   '기니비사우🇬🇼',
#   '모리셔스🇲🇺',
#   '바베이도스🇧🇧',
#   '코모로🇰🇲',
#   '리히텐슈타인🇱🇮',
#   '모나코🇲🇨',
#   '신트마르턴🇸🇽',
#   '뉴질랜드🇳🇿',
#   '세인트마틴 섬🇲🇫',
#   '버뮤다🇧🇲',
#   '부탄🇧🇹',
#   '터크스 케이커스 제도🇹🇨',
#   '영국령 버진아일랜드🇻🇬',
#   '상투메 프린시페🇸🇹',
#   '세인트빈센트 그레나딘🇻🇨',
#   '카리브 네덜란드🇧🇶',
#   '생바르텔레미🇧🇱',
#   '앤티가 바부다🇦🇬',
#   '탄자니아🇹🇿',
#   '페로 제도🇫🇴',
#   '케이맨 제도🇰🇾',
#   '세인트키츠 네비스🇰🇳',
#   '왈리스 퓌티나🇼🇫',
#   '브루나이🇧🇳',
#   '도미니카 연방🇩🇲',
#   '그린란드🇬🇱',
#   '그레나다🇬🇩',
#   '뉴칼레도니아🇳🇨',
#   '앵귈라🇦🇮',
#   '포클랜드 제도🇫🇰',
#   '마카오🇲🇴',
#   '생피에르 미클롱🇵🇲',
#   '바티칸 시국🇻🇦',
#   '몬트세랫🇲🇸',
#   '솔로몬 제도🇸🇧',
#   '서사하라🇪🇭',
#   '잔담(크루즈)🚢',
#   '마셜 제도🇲🇭',
#   '바누아투🇻🇺',
#   '사모아🇼🇸',
#   '세인트헬레나🇸🇭',
#   '미크로네시아🇫🇲'],
#  ['36,449,535\n(+144,461)',
#   '31,902,422\n(+40,647)',
#   '20,108,746\n(+42,159)',
#   '6,424,884\n(+22,320)',
#   '6,258,953\n(+25,077)',
#   '6,014,023\n(+31,442)',
#   '5,870,741\n(+23,957)',
#   '5,002,951\n(+13,549)',
#   '4,828,583\n(+6,980)',
#   '4,588,132\n(+21,561)',
#   '4,383,787\n(+6,599)',
#   '4,119,110\n(+26,439)',
#   '3,793,341\n(+2,826)',
#   '3,639,616\n(+31,753)',
#   '2,944,226\n(+21,563)',
#   '2,883,976\n(+180)',
#   '2,511,178\n(+13,523)',
#   '2,258,532\n(+1,054)',
#   '2,122,557\n(+1,496)',
#   '1,883,513\n(+2,392)',
#   '1,704,363\n(+7,973)',
#   '1,674,726\n(+149)',
#   '1,649,341\n(+10,996)',
#   '1,621,571\n(+1,182)',
#   '1,437,701\n(+1,519)',
#   '1,343,396\n(+8,136)',
#   '1,243,852\n(+19,257)',
#   '1,136,726\n(+1,819)',
#   '1,104,538',
#   '1,084,711\n(+255)',
#   '1,063,125\n(+4,720)',
#   '1,018,554\n(+15,749)',
#   '984,985\n(+2,621)',
#   '893,105\n(+1,294)',
#   '809,855',
#   '775,782\n(+531)',
#   '736,522\n(+21,838)',
#   '725,245\n(+584)',
#   '723,968',
#   '712,740\n(+2,231)',
#   '691,554\n(+1,545)',
#   '676,683\n(+11,358)',
#   '662,529\n(+607)',
#   '626,412\n(+7,899)',
#   '608,114\n(+2,909)',
#   '568,505\n(+1,461)',
#   '532,785\n(+850)',
#   '509,596\n(+2,924)',
#   '491,185\n(+829)',
#   '477,262\n(+467)',
#   '454,542\n(+348)',
#   '452,953\n(+1,213)',
#   '444,569\n(+4,216)',
#   '440,494\n(+895)',
#   '439,899\n(+8,886)',
#   '427,481\n(+549)',
#   '416,677\n(+1,932)',
#   '402,293\n(+596)',
#   '393,007\n(+44)',
#   '385,512\n(+3,998)',
#   '382,295\n(+140)',
#   '364,832\n(+233)',
#   '350,605\n(+1,289)',
#   '343,829\n(+317)',
#   '326,043\n(+4,614)',
#   '322,965\n(+946)',
#   '322,838',
#   '317,703',
#   '310,960\n(+979)',
#   '310,628\n(+3,609)',
#   '305,936\n(+1,755)',
#   '298,020',
#   '285,726\n(+517)',
#   '284,580\n(+57)',
#   '283,082\n(+584)',
#   '269,848\n(+111)',
#   '264,827\n(+1,879)',
#   '260,424\n(+241)',
#   '260,041\n(+132)',
#   '231,923\n(+298)',
#   '227,472\n(+199)',
#   '211,028\n(+1,205)',
#   '209,227\n(+1,823)',
#   '206,106',
#   '199,662\n(+527)',
#   '197,175\n(+8,109)',
#   '179,216\n(+1,203)',
#   '177,142\n(+565)',
#   '172,069\n(+972)',
#   '168,415\n(+681)',
#   '157,627\n(+701)',
#   '150,458\n(+218)',
#   '140,204\n(+249)',
#   '139,347\n(+63)',
#   '135,738\n(+912)',
#   '134,950\n(+230)',
#   '133,591\n(+149)',
#   '130,526\n(+1,490)',
#   '122,574',
#   '120,814\n(+319)',
#   '115,445\n(+956)',
#   '110,885\n(+165)',
#   '107,507',
#   '106,434',
#   '104,994\n(+525)',
#   '103,443\n(+285)',
#   '95,226',
#   '93,608\n(+100)',
#   '88,371',
#   '82,064',
#   '81,335\n(+522)',
#   '78,130\n(+131)',
#   '74,993\n(+629)',
#   '74,262\n(+50)',
#   '66,898\n(+648)',
#   '65,686\n(+81)',
#   '55,218\n(+503)',
#   '54,165\n(+326)',
#   '51,523\n(+269)',
#   '51,028\n(+135)',
#   '43,487\n(+218)',
#   '42,685',
#   '40,245',
#   '39,577',
#   '37,138',
#   '36,322\n(+682)',
#   '36,051\n(+353)',
#   '34,787\n(+71)',
#   '33,976\n(+35)',
#   '30,875\n(+119)',
#   '30,377\n(+980)',
#   '27,596\n(+365)',
#   '26,630\n(+153)',
#   '26,071\n(+12)',
#   '25,853\n(+137)',
#   '25,462\n(+22)',
#   '23,821',
#   '23,029',
#   '22,843\n(+54)',
#   '22,459\n(+654)',
#   '20,363\n(+37)',
#   '19,531\n(+13)',
#   '18,582',
#   '17,774',
#   '16,559\n(+158)',
#   '15,775\n(+10)',
#   '15,735',
#   '15,513\n(+73)',
#   '15,419\n(+228)',
#   '14,836\n(+27)',
#   '14,633\n(+18)',
#   '14,438\n(+56)',
#   '13,988\n(+81)',
#   '13,610\n(+11)',
#   '13,603',
#   '13,216',
#   '12,262\n(+262)',
#   '12,011\n(+7)',
#   '11,659\n(+3)',
#   '11,475\n(+89)',
#   '11,100\n(+10)',
#   '9,853',
#   '8,940',
#   '8,738\n(+125)',
#   '8,608',
#   '8,603\n(+98)',
#   '8,132\n(+354)',
#   '8,088\n(+374)',
#   '7,151',
#   '7,131\n(+27)',
#   '6,576\n(+3)',
#   '6,310\n(+7)',
#   '5,713\n(+25)',
#   '5,676\n(+7)',
#   '5,459',
#   '5,337\n(+102)',
#   '5,147',
#   '5,116\n(+15)',
#   '4,977\n(+1)',
#   '4,702\n(+23)',
#   '4,592',
#   '4,455\n(+12)',
#   '4,031\n(+1)',
#   '3,099\n(+5)',
#   '2,973\n(+12)',
#   '2,924\n(+33)',
#   '2,880',
#   '2,713\n(+134)',
#   '2,614\n(+25)',
#   '2,544',
#   '2,514\n(+15)',
#   '2,500',
#   '2,468\n(+3)',
#   '2,298',
#   '1,715\n(+2)',
#   '1,336\n(+141)',
#   '1,328\n(+8)',
#   '1,017',
#   '987',
#   '646\n(+2)',
#   '611\n(+8)',
#   '445',
#   '339',
#   '218',
#   '168\n(+17)',
#   '164',
#   '134',
#   '113',
#   '66',
#   '63',
#   '28',
#   '27',
#   '22\n(+1)',
#   '20',
#   '10',
#   '9',
#   '4',
#   '4',
#   '3',
#   '2',
#   '1'],
#  ['13,081\n(+210)',
#   '8,944',
#   '8,318',
#   '2,300',
#   '1,458\n(+38)',
#   '871\n(-10)',
#   '543',
#   '3,657\n(-57)',
#   '8,155',
#   '1,928\n(+3)',
#   '277\n(+9)',
#   '6,375\n(+96)',
#   '417\n(+24)',
#   'N/A',
#   '4,798',
#   '44\n(+2)',
#   '546',
#   '177',
#   '1,690\n(-18)',
#   '213\n(+3)',
#   '953\n(-15)',
#   '11',
#   '2,253',
#   '1,223\n(-18)',
#   '202\n(-29)',
#   '1,389\n(+23)',
#   '1,097\n(+1)',
#   '94\n(+2)',
#   '24',
#   '73\n(+5)',
#   '4,275\n(+118)',
#   '1,072\n(+48)',
#   '186\n(-8)',
#   '257\n(+4)',
#   '12',
#   '590\n(-17)',
#   '5,159\n(+160)',
#   '14\n(+2)',
#   '51',
#   'N/A',
#   'N/A',
#   '1,010\n(+115)',
#   '40\n(+7)',
#   '221',
#   '630',
#   '54',
#   '1,404',
#   '191\n(-1)',
#   '759',
#   '200',
#   '292\n(-5)',
#   'N/A',
#   'N/A',
#   '133',
#   '407',
#   '91\n(+2)',
#   '380',
#   '256\n(-15)',
#   '8',
#   '5',
#   '35',
#   '18\n(+2)',
#   'N/A',
#   '176\n(+7)',
#   'N/A',
#   '12',
#   'N/A',
#   '11',
#   '681',
#   '33\n(+5)',
#   '662',
#   '189',
#   '50\n(+12)',
#   '90',
#   '276\n(+6)',
#   '4',
#   'N/A',
#   '84\n(-2)',
#   '8\n(+1)',
#   'N/A',
#   '22\n(-2)',
#   '108',
#   '377\n(+1)',
#   'N/A',
#   '316\n(-27)',
#   'N/A',
#   '52\n(+17)',
#   '11',
#   '192',
#   '195',
#   'N/A',
#   '1,124',
#   '3',
#   '8\n(+1)',
#   '23',
#   '5\n(+2)',
#   '3',
#   '32',
#   '1',
#   '73\n(+5)',
#   '12',
#   '18',
#   'N/A',
#   '36',
#   '85',
#   '6',
#   '560',
#   'N/A',
#   '151',
#   '152',
#   'N/A',
#   '11',
#   '44\n(+7)',
#   '5',
#   '65\n(+1)',
#   '7\n(-1)',
#   '285',
#   '52\n(+15)',
#   'N/A',
#   'N/A',
#   '8',
#   '27',
#   '45',
#   '22',
#   'N/A',
#   '40',
#   '59',
#   '4',
#   '23',
#   '31',
#   '10',
#   '16',
#   '24',
#   'N/A',
#   '22\n(+1)',
#   '8',
#   '23',
#   '1',
#   '13',
#   '5',
#   'N/A',
#   'N/A',
#   'N/A',
#   '7',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A',
#   '11',
#   'N/A',
#   'N/A',
#   '4',
#   '4',
#   'N/A',
#   'N/A',
#   'N/A',
#   '14',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A',
#   '1',
#   '21',
#   '5',
#   '3',
#   'N/A',
#   'N/A',
#   '2',
#   '23',
#   'N/A',
#   'N/A',
#   '3\n(+1)',
#   'N/A',
#   '2',
#   '1',
#   'N/A',
#   '11\n(-4)',
#   'N/A',
#   '4',
#   'N/A',
#   'N/A',
#   'N/A',
#   '1',
#   '6\n(+3)',
#   '2',
#   'N/A',
#   '7',
#   'N/A',
#   'N/A',
#   '1\n(+1)',
#   '27',
#   'N/A',
#   '2',
#   'N/A',
#   'N/A',
#   '4',
#   '7',
#   'N/A',
#   'N/A',
#   '1',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A',
#   'N/A'],
#  ['632,647\n(+748)',
#   '427,565\n(+657)',
#   '561,807\n(+1,006)',
#   '164,094\n(+793)',
#   '112,158\n(+60)',
#   '130,178\n(+92)',
#   '51,976\n(+101)',
#   '107,213\n(+190)',
#   '122,087\n(+188)',
#   '82,006\n(+75)',
#   '128,187\n(+24)',
#   '93,473\n(+387)',
#   '92,271\n(+14)',
#   '105,598\n(+1,588)',
#   '243,733\n(+568)',
#   '75,285\n(+4)',
#   '74,352\n(+479)',
#   '53,085\n(+20)',
#   '196,818\n(+58)',
#   '17,867\n(+9)',
#   '19,146\n(+59)',
#   '30,363',
#   '28,835\n(+162)',
#   '35,880\n(+74)',
#   '26,654\n(+17)',
#   '22,411\n(+261)',
#   '10,389\n(+210)',
#   '25,268\n(+4)',
#   '14,620',
#   '34,313\n(+8)',
#   '23,797\n(+95)',
#   '15,288\n(+14)',
#   '17,457\n(+17)',
#   '6,516\n(+7)',
#   '30,033',
#   '10,105\n(+5)',
#   '6,066\n(+212)',
#   '7,135\n(+2)',
#   '10,909',
#   '10,038\n(+19)',
#   '1,971\n(+2)',
#   '10,163\n(+76)',
#   '10,750\n(+2)',
#   '6,659\n(+128)',
#   '20,809\n(+130)',
#   '7,932\n(+6)',
#   '8,320\n(+9)',
#   '13,021\n(+21)',
#   '31,774\n(+20)',
#   '17,959\n(+24)',
#   '15,238\n(+31)',
#   '3,523\n(+10)',
#   '6,054\n(+38)',
#   '6,885\n(+10)',
#   '3,259\n(+75)',
#   '18,251\n(+8)',
#   '5,124\n(+16)',
#   '2,361\n(+5)',
#   '12,541',
#   '10,644\n(+66)',
#   '5,986\n(+4)',
#   '8,271\n(+1)',
#   '5,056\n(+5)',
#   '3,973\n(+2)',
#   '5,017\n(+196)',
#   '2,552',
#   '11,262',
#   '3,611',
#   '3,682\n(+16)',
#   '5,044',
#   '8,120\n(+68)',
#   '3,906',
#   '4,424',
#   '16,562\n(+5)',
#   '4,415\n(+9)',
#   '1,384',
#   '3,689\n(+26)',
#   '6,275\n(+5)',
#   '4,431\n(+1)',
#   '4,641\n(+5)',
#   '601',
#   '4,117\n(+29)',
#   '2,116\n(+3)',
#   '9,691',
#   '3,474\n(+15)',
#   '3,016\n(+296)',
#   '4,487\n(+46)',
#   '2,181\n(+3)',
#   '846\n(+5)',
#   '2,389\n(+9)',
#   '5,503\n(+2)',
#   '6,908\n(+10)',
#   '804',
#   '2,559',
#   '923\n(+7)',
#   '1,277\n(+1)',
#   '2,458\n(+1)',
#   '1,566\n(+28)',
#   '1,704',
#   '3,182\n(+24)',
#   '3,805\n(+51)',
#   '984',
#   '2,269',
#   '854',
#   '437\n(+4)',
#   '1,635',
#   '2,771',
#   '4,636',
#   '2,691',
#   '1,334',
#   '1,537\n(+11)',
#   '222',
#   '874\n(+14)',
#   '824',
#   '1,467\n(+10)',
#   '41\n(+1)',
#   '1,776\n(+28)',
#   '1,214\n(+3)',
#   '1,048\n(+3)',
#   '338',
#   '1,042\n(+10)',
#   '943',
#   '288',
#   '1,117',
#   '2,776',
#   '296\n(+6)',
#   '939\n(+6)',
#   '424',
#   '298',
#   '193',
#   '835\n(+8)',
#   '592\n(+9)',
#   '248\n(+5)',
#   '1,919',
#   '659\n(+1)',
#   '165',
#   '247',
#   '129',
#   '554\n(+1)',
#   '157\n(+2)',
#   '566\n(+3)',
#   '174',
#   '94',
#   '192',
#   '156',
#   '806\n(+12)',
#   '837',
#   '122',
#   '295',
#   '128',
#   '534',
#   '339\n(+1)',
#   '131\n(+1)',
#   '169',
#   '377',
#   '178',
#   '111',
#   '212',
#   '156',
#   '26',
#   '120',
#   '196',
#   '123',
#   '30',
#   '110',
#   '242\n(+4)',
#   '8\n(+1)',
#   '38',
#   '98',
#   '1,384\n(+1)',
#   '35',
#   '120',
#   '90',
#   '196',
#   '148',
#   '33',
#   '90',
#   '95',
#   '174',
#   '79',
#   '20',
#   '48',
#   '147',
#   '59',
#   '33',
#   '34',
#   '26',
#   '39\n(+1)',
#   '33',
#   '2',
#   '18',
#   '31',
#   '37',
#   '12',
#   '17',
#   '2\n(+1)',
#   '43',
#   '21',
#   '2',
#   '2',
#   '3',
#   '7',
#   '3',
#   '0',
#   '0',
#   '1',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '1',
#   '0',
#   '1',
#   '2',
#   '0',
#   '1',
#   '0',
#   '0',
#   '0'],
#  ['29,834,481\n(+28,888)',
#   '31,055,861\n(+40,017)',
#   '18,868,602\n(+28,370)',
#   '5,739,838\n(+19,485)',
#   '5,743,040\n(+10,889)',
#   '4,599,885\n(+14,470)',
#   '5,491,762\n(+6,941)',
#   '4,645,158\n(+14,722)',
#   '4,632,801\n(+8,132)',
#   '3,784,544\n(+10,588)',
#   '4,150,915\n(+2,936)',
#   '3,515,263\n(+22,795)',
#   '3,664,100\n(+1,400)',
#   '3,036,194\n(+39,716)',
#   '2,298,074\n(+14,535)',
#   '2,654,359\n(+135)',
#   '2,280,490\n(+12,405)',
#   '2,190,686\n(+1,393)',
#   'N/A',
#   'N/A',
#   '1,520,000\n(+9,112)',
#   '1,641,904\n(+295)',
#   '1,544,443\n(+9,068)',
#   '1,576,801\n(+559)',
#   '1,401,224\n(+642)',
#   '1,188,820\n(+16,383)',
#   '1,009,343\n(+16,323)',
#   '1,063,847\n(+1,400)',
#   'N/A',
#   '1,048,481\n(+77)',
#   '959,491\n(+4,780)',
#   '874,170\n(+8,744)',
#   '923,510\n(+3,232)',
#   '858,260\n(+483)',
#   '752,709',
#   '753,332\n(+326)',
#   '517,012\n(+21,108)',
#   '711,684\n(+226)',
#   '693,449',
#   '667,270\n(+1,722)',
#   '668,554\n(+1,480)',
#   '598,958\n(+8,926)',
#   '645,694\n(+422)',
#   '514,299\n(+6,638)',
#   '539,339\n(+4,018)',
#   '538,434\n(+395)',
#   '514,362\n(+975)',
#   '462,919\n(+1,541)',
#   '443,880',
#   '413,821\n(+912)',
#   '425,858\n(+909)',
#   '447,059\n(+1,169)',
#   '397,240\n(+1,735)',
#   '422,467\n(+1,204)',
#   '390,505\n(+8,364)',
#   '398,857\n(+89)',
#   '337,423\n(+1,913)',
#   '390,759\n(+961)',
#   '379,761\n(+43)',
#   '336,444\n(+2,486)',
#   '374,567\n(+181)',
#   '355,360\n(+170)',
#   '334,667\n(+409)',
#   '325,873\n(+696)',
#   '290,794\n(+4,429)',
#   '308,549\n(+726)',
#   '234,454',
#   '312,415',
#   '296,599\n(+1,011)',
#   '271,060\n(+1,066)',
#   '103,110\n(+244)',
#   '282,763',
#   '270,697\n(+476)',
#   '232,601\n(+321)',
#   '264,225\n(+60)',
#   '267,406\n(+105)',
#   '197,563\n(+849)',
#   '252,693\n(+145)',
#   '254,192\n(+92)',
#   '221,043\n(+218)',
#   '224,703\n(+173)',
#   '197,029\n(+1,242)',
#   '183,789\n(+1,737)',
#   '190,665',
#   '191,836\n(+672)',
#   '62,332\n(+4,292)',
#   '119,888\n(+736)',
#   '165,409\n(+86)',
#   '162,678\n(+2,189)',
#   '155,447\n(+1,513)',
#   '150,506\n(+36)',
#   '102,827\n(+677)',
#   '88,952',
#   '135,875\n(+42)',
#   '129,182\n(+991)',
#   '129,595\n(+173)',
#   '130,370\n(+27)',
#   '101,875\n(+542)',
#   '104,731',
#   '99,055\n(+677)',
#   '86,526\n(+1,637)',
#   '46,000',
#   '105,323',
#   '98,814',
#   '80,178',
#   '99,413\n(+134)',
#   '88,502',
#   '87,526\n(+34)',
#   '76,952',
#   '80,433',
#   '74,745\n(+700)',
#   '75,353\n(+100)',
#   '44,948\n(+25)',
#   '72,536\n(+89)',
#   '50,101\n(+410)',
#   '63,536\n(+79)',
#   '40,711\n(+261)',
#   '47,152\n(+25)',
#   '30,189\n(+146)',
#   '49,789\n(+79)',
#   '40,012\n(+165)',
#   '41,177',
#   '35,563',
#   '32,637',
#   '30,867',
#   '11,798\n(+297)',
#   '30,462',
#   '32,909\n(+147)',
#   '33,230\n(+25)',
#   '9,995',
#   '22,796\n(+350)',
#   '23,228\n(+189)',
#   '24,669\n(+72)',
#   '22,034\n(+7)',
#   '22,106\n(+71)',
#   '25,248\n(+20)',
#   '2,250',
#   '104',
#   '21,512\n(+39)',
#   '19,825\n(+12)',
#   '15,110\n(+308)',
#   '2,964',
#   '17,992',
#   '17,384',
#   '14,785\n(+63)',
#   '13,053\n(+35)',
#   '7,695',
#   '15,036\n(+88)',
#   '12,824\n(+42)',
#   '14,444\n(+28)',
#   '13,982\n(+5)',
#   '13,622\n(+33)',
#   '13,297\n(+81)',
#   '13,391\n(+6)',
#   '6,664',
#   '12,421',
#   '11,397\n(+138)',
#   '11,724\n(+3)',
#   '11,495',
#   '10,114\n(+19)',
#   '10,514',
#   '4,225',
#   '8,730',
#   '7,254\n(+92)',
#   '8,136',
#   '7,536\n(+113)',
#   '3,946\n(+59)',
#   '773',
#   '6,859',
#   '4,305\n(+34)',
#   '6,487\n(+3)',
#   '4,299\n(+6)',
#   '5,416\n(+12)',
#   '5,359\n(+5)',
#   '2,715',
#   '4,321\n(+302)',
#   '5,009',
#   '4,771\n(+102)',
#   '4,796',
#   '4,099\n(+43)',
#   '1,854',
#   '4,310\n(+59)',
#   '3,875\n(+2)',
#   '3,022',
#   '2,790\n(+20)',
#   '2,703\n(+13)',
#   '2,824',
#   '1,399',
#   '2,510\n(+7)',
#   '2,460',
#   '2,439\n(+1)',
#   '1,914',
#   '2,368\n(+3)',
#   '2,233',
#   '1,673',
#   '462',
#   '1,246\n(+2)',
#   '183',
#   '963',
#   '639\n(+4)',
#   '558\n(+9)',
#   '438',
#   '289',
#   '209',
#   '101\n(+11)',
#   '161',
#   '58',
#   '111',
#   '63',
#   '57\n(+1)',
#   '26',
#   '27',
#   '20',
#   '20',
#   '8',
#   '7',
#   '4',
#   '3',
#   '3',
#   '2',
#   '1'],
#  ['1.7',
#   '1.3',
#   '2.8',
#   '2.6',
#   '1.8',
#   '2.2',
#   '0.9',
#   '2.1',
#   '2.5',
#   '1.8',
#   '2.9',
#   '2.3',
#   '2.4',
#   '2.9',
#   '8.3',
#   '2.6',
#   '3.0',
#   '2.4',
#   '9.3',
#   '0.9',
#   '1.1',
#   '1.8',
#   '1.7',
#   '2.2',
#   '1.9',
#   '1.7',
#   '0.8',
#   '2.2',
#   '1.3',
#   '3.2',
#   '2.2',
#   '1.5',
#   '1.8',
#   '0.7',
#   '3.7',
#   '1.3',
#   '0.8',
#   '1.0',
#   '1.5',
#   '1.4',
#   '0.3',
#   '1.5',
#   '1.6',
#   '1.1',
#   '3.4',
#   '1.4',
#   '1.6',
#   '2.6',
#   '6.5',
#   '3.8',
#   '3.4',
#   '0.8',
#   '1.4',
#   '1.6',
#   '0.7',
#   '4.3',
#   '1.2',
#   '0.6',
#   '3.2',
#   '2.8',
#   '1.6',
#   '2.3',
#   '1.4',
#   '1.2',
#   '1.5',
#   '0.8',
#   '3.5',
#   '1.1',
#   '1.2',
#   '1.6',
#   '2.7',
#   '1.3',
#   '1.5',
#   '5.8',
#   '1.6',
#   '0.5',
#   '1.4',
#   '2.4',
#   '1.7',
#   '2.0',
#   '0.3',
#   '2.0',
#   '1.0',
#   '4.7',
#   '1.7',
#   '1.5',
#   '2.5',
#   '1.2',
#   '0.5',
#   '1.4',
#   '3.5',
#   '4.6',
#   '0.6',
#   '1.8',
#   '0.7',
#   '0.9',
#   '1.8',
#   '1.2',
#   '1.4',
#   '2.6',
#   '3.3',
#   '0.9',
#   '2.1',
#   '0.8',
#   '0.4',
#   '1.6',
#   '2.9',
#   '5.0',
#   '3.0',
#   '1.6',
#   '1.9',
#   '0.3',
#   '1.2',
#   '1.1',
#   '2.2',
#   '0.1',
#   '3.2',
#   '2.2',
#   '2.0',
#   '0.7',
#   '2.4',
#   '2.2',
#   '0.7',
#   '2.8',
#   '7.5',
#   '0.8',
#   '2.6',
#   '1.2',
#   '0.9',
#   '0.6',
#   '2.7',
#   '2.1',
#   '0.9',
#   '7.4',
#   '2.5',
#   '0.6',
#   '1.0',
#   '0.6',
#   '2.4',
#   '0.7',
#   '2.8',
#   '0.9',
#   '0.5',
#   '1.1',
#   '0.9',
#   '5.1',
#   '5.3',
#   '0.8',
#   '1.9',
#   '0.9',
#   '3.6',
#   '2.3',
#   '0.9',
#   '1.2',
#   '2.8',
#   '1.3',
#   '0.9',
#   '1.8',
#   '1.3',
#   '0.2',
#   '1.1',
#   '2.0',
#   '1.4',
#   '0.3',
#   '1.3',
#   '2.8',
#   '0.1',
#   '0.5',
#   '1.4',
#   '19.4',
#   '0.5',
#   '1.9',
#   '1.6',
#   '3.5',
#   '2.7',
#   '0.6',
#   '1.7',
#   '1.9',
#   '3.5',
#   '1.7',
#   '0.4',
#   '1.1',
#   '3.6',
#   '1.9',
#   '1.1',
#   '1.2',
#   '0.9',
#   '1.4',
#   '1.3',
#   '0.1',
#   '0.7',
#   '1.2',
#   '1.5',
#   '0.5',
#   '1.0',
#   '0.1',
#   '3.2',
#   '2.1',
#   '0.2',
#   '0.3',
#   '0.5',
#   '1.6',
#   '0.9',
#   '-',
#   '-',
#   '0.6',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '-',
#   '4.5',
#   '-',
#   '10',
#   '22.2',
#   '-',
#   '25',
#   '-',
#   '-',
#   '-'],
#  ['81.9',
#   '97.3',
#   '93.8',
#   '89.3',
#   '91.8',
#   '76.5',
#   '93.5',
#   '92.8',
#   '95.9',
#   '82.5',
#   '94.7',
#   '85.3',
#   '96.6',
#   '83.4',
#   '78.1',
#   '92.0',
#   '90.8',
#   '97.0',
#   'N/A',
#   'N/A',
#   '89.2',
#   '98.0',
#   '93.6',
#   '97.2',
#   '97.5',
#   '88.5',
#   '81.1',
#   '93.6',
#   'N/A',
#   '96.7',
#   '90.3',
#   '85.8',
#   '93.8',
#   '96.1',
#   '92.9',
#   '97.1',
#   '70.2',
#   '98.1',
#   '95.8',
#   '93.6',
#   '96.7',
#   '88.5',
#   '97.5',
#   '82.1',
#   '88.7',
#   '94.7',
#   '96.5',
#   '90.8',
#   '90.4',
#   '86.7',
#   '93.7',
#   '98.7',
#   '89.4',
#   '95.9',
#   '88.8',
#   '93.3',
#   '81.0',
#   '97.1',
#   '96.6',
#   '87.3',
#   '98.0',
#   '97.4',
#   '95.5',
#   '94.8',
#   '89.2',
#   '95.5',
#   '72.6',
#   '98.3',
#   '95.4',
#   '87.3',
#   '33.7',
#   '94.9',
#   '94.7',
#   '81.7',
#   '93.3',
#   '99.1',
#   '74.6',
#   '97.0',
#   '97.8',
#   '95.3',
#   '98.8',
#   '93.4',
#   '87.8',
#   '92.5',
#   '96.1',
#   '31.6',
#   '66.9',
#   '93.4',
#   '94.5',
#   '92.3',
#   '95.5',
#   '68.3',
#   '63.4',
#   '97.5',
#   '95.2',
#   '96.0',
#   '97.6',
#   '78.0',
#   '85.4',
#   '82.0',
#   '74.9',
#   '41.5',
#   '98.0',
#   '92.8',
#   '76.4',
#   '96.1',
#   '92.9',
#   '93.5',
#   '87.1',
#   '98.0',
#   '91.9',
#   '96.4',
#   '59.9',
#   '97.7',
#   '74.9',
#   '96.7',
#   '73.7',
#   '87.1',
#   '58.6',
#   '97.6',
#   '92.0',
#   '96.5',
#   '88.4',
#   '82.5',
#   '83.1',
#   '32.5',
#   '84.5',
#   '94.6',
#   '97.8',
#   '32.4',
#   '75.0',
#   '84.2',
#   '92.6',
#   '84.5',
#   '85.5',
#   '99.2',
#   '9.4',
#   '0.5',
#   '94.2',
#   '88.3',
#   '74.2',
#   '15.2',
#   '96.8',
#   '97.8',
#   '89.3',
#   '82.7',
#   '48.9',
#   '96.9',
#   '83.2',
#   '97.4',
#   '95.6',
#   '94.3',
#   '95.1',
#   '98.4',
#   '49.0',
#   '94.0',
#   '92.9',
#   '97.6',
#   '98.6',
#   '88.1',
#   '94.7',
#   '42.9',
#   '97.7',
#   '83.0',
#   '94.5',
#   '87.6',
#   '48.5',
#   '9.6',
#   '95.9',
#   '60.4',
#   '98.6',
#   '68.1',
#   '94.8',
#   '94.4',
#   '49.7',
#   '81.0',
#   '97.3',
#   '93.3',
#   '96.4',
#   '87.2',
#   '40.4',
#   '96.7',
#   '96.1',
#   '97.5',
#   '93.8',
#   '92.4',
#   '98.1',
#   '51.6',
#   '96.0',
#   '96.7',
#   '97.0',
#   '76.6',
#   '95.9',
#   '97.2',
#   '97.6',
#   '34.6',
#   '93.8',
#   '18.0',
#   '97.6',
#   '98.9',
#   '91.3',
#   '98.4',
#   '85.3',
#   '95.9',
#   '60.1',
#   '98.2',
#   '43.3',
#   '98.2',
#   '95.5',
#   '90.5',
#   '92.9',
#   '100',
#   '90.9',
#   '100',
#   '80',
#   '77.8',
#   '100',
#   '75',
#   '100',
#   '100',
#   '100'],
#  ['110,328',
#   '23,141',
#   '94,805',
#   '44,026',
#   '96,283',
#   '89,006',
#   '69,906',
#   '110,912',
#   '95,015',
#   '98,132',
#   '72,619',
#   '49,041',
#   '45,302',
#   '13,306',
#   '22,991',
#   '76,202',
#   '42,548',
#   '51,657',
#   '64,422',
#   '109,923',
#   '42,373',
#   '156,385',
#   '15,051',
#   '84,876',
#   '38,106',
#   '8,157',
#   '38,431',
#   '98,081',
#   '109,368',
#   '56,385',
#   '4,833',
#   '8,053',
#   '96,598',
#   '103,671',
#   '83,833',
#   '76,073',
#   '10,838',
#   '83,005',
#   '83,651',
#   '24,462',
#   '69,922',
#   '18,620',
#   '73,562',
#   '33,777',
#   '51,454',
#   '83,525',
#   '15,304',
#   '49,155',
#   '27,840',
#   '40,886',
#   '63,773',
#   '47,935',
#   '112,282',
#   '102,280',
#   '39,623',
#   '61,578',
#   '81,796',
#   '94,319',
#   '71,984',
#   '21,741',
#   '110,072',
#   '88,869',
#   '34,579',
#   '31,725',
#   '15,273',
#   '55,759',
#   '6,001',
#   '62,277',
#   '10,976',
#   '62,908',
#   '30,888',
#   '58,359',
#   '104,958',
#   '2,781',
#   '2,467',
#   '158,647',
#   '38,541',
#   '64,590',
#   '125,084',
#   '78,267',
#   '78,954',
#   '3,925',
#   '4,115',
#   '62,822',
#   '10,861',
#   '2,113',
#   '4,113',
#   '862',
#   '52,934',
#   '25,906',
#   '75,659',
#   '3,865',
#   '25,910',
#   '73,877',
#   '4,082',
#   '101,731',
#   '46,470',
#   '4,217',
#   '52,123',
#   '47,548',
#   '7,797',
#   '20,013',
#   '59,381',
#   '3,435',
#   '87,458',
#   '164,701',
#   '2,087',
#   '65',
#   '13,624',
#   '3,091',
#   '4,898',
#   '144,749',
#   '5,840',
#   '118,634',
#   '3,995',
#   '11,228',
#   '2,912',
#   '18,398',
#   '575',
#   '1,941',
#   '1,326',
#   '1,541',
#   '44,951',
#   '28,656',
#   '847',
#   '40,518',
#   '1,425',
#   '78,785',
#   '61,170',
#   '103,371',
#   '26,537',
#   '6,013',
#   '2,044',
#   '1,490',
#   '44,179',
#   '11,440',
#   '59,534',
#   '61,367',
#   '29,155',
#   '79,951',
#   '1,786',
#   '71,591',
#   '188,943',
#   '1,987',
#   '2,021',
#   '662',
#   '993',
#   '1,634',
#   '39,210',
#   '192,014',
#   '723',
#   '36,310',
#   '85,653',
#   '651',
#   '6,350',
#   '2,395',
#   '115,870',
#   '1,602',
#   '11,801',
#   '8,703',
#   '992',
#   '1,487',
#   '6,372',
#   '25,606',
#   '710',
#   '3,560',
#   '1,118',
#   '680',
#   '1,481',
#   '239',
#   '1,854',
#   '791',
#   '31,471',
#   '235',
#   '1,079',
#   '63,822',
#   '151,690',
#   '151,851',
#   '303',
#   '2,421',
#   '3,611',
#   '15,502',
#   '4,635',
#   '81,279',
#   '75,761',
#   '68,803',
#   '598',
#   '70,165',
#   '41,973',
#   '3,297',
#   '64,933',
#   '82,697',
#   '11,270',
#   '20,714',
#   '65,591',
#   '135,264',
#   '13,561',
#   '17',
#   '20,199',
#   '9,829',
#   '11,485',
#   '-',
#   '775',
#   '5,098',
#   '2,959',
#   '1,457',
#   '469',
#   '7,532',
#   '18,966',
#   '97',
#   '4,833',
#   '33,708',
#   '4,407',
#   '29',
#   '17',
#   '-',
#   '68',
#   '13',
#   '15',
#   '329',
#   '9'],
#  ['331,002,651',
#   '1,380,004,385',
#   '212,559,417',
#   '145,934,462',
#   '65,273,511',
#   '67,886,011',
#   '84,339,067',
#   '45,195,774',
#   '50,882,891',
#   '46,754,778',
#   '60,461,826',
#   '83,992,949',
#   '83,783,942',
#   '273,523,615',
#   '128,932,753',
#   '37,846,611',
#   '59,308,690',
#   '43,733,762',
#   '32,971,854',
#   '17,134,872',
#   '40,222,493',
#   '10,708,981',
#   '109,581,078',
#   '19,116,201',
#   '37,742,154',
#   '164,689,383',
#   '32,365,999',
#   '11,589,623',
#   '10,099,265',
#   '19,237,691',
#   '220,892,340',
#   '126,476,461',
#   '10,196,709',
#   '8,655,535',
#   '9,660,351',
#   '10,203,134',
#   '69,799,978',
#   '8,737,371',
#   '8,654,622',
#   '29,136,808',
#   '9,890,402',
#   '36,910,560',
#   '9,006,398',
#   '18,776,707',
#   '11,818,619',
#   '6,825,445',
#   '34,813,871',
#   '10,423,054',
#   '17,643,054',
#   '11,673,021',
#   '7,132,538',
#   '9,449,323',
#   '3,989,167',
#   '4,314,767',
#   '11,326,616',
#   '6,948,445',
#   '5,094,118',
#   '4,270,571',
#   '5,459,642',
#   '17,915,568',
#   '3,473,730',
#   '4,105,267',
#   '10,139,177',
#   '10,847,910',
#   '21,413,249',
#   '5,792,202',
#   '54,409,800',
#   '5,101,414',
#   '28,435,940',
#   '4,937,786',
#   '9,904,607',
#   '5,106,626',
#   '2,722,289',
#   '102,334,404',
#   '114,963,588',
#   '1,701,575',
#   '6,871,292',
#   '4,033,963',
#   '2,078,938',
#   '2,963,243',
#   '2,881,053',
#   '53,771,296',
#   '51,269,185',
#   '3,280,819',
#   '18,383,955',
#   '97,338,579',
#   '43,851,044',
#   '206,139,589',
#   '3,278,290',
#   '6,524,195',
#   '2,083,374',
#   '38,928,346',
#   '5,421,241',
#   '1,886,198',
#   '33,469,203',
#   '1,326,535',
#   '2,877,797',
#   '31,255,435',
#   '2,351,627',
#   '2,540,905',
#   '14,862,924',
#   '5,540,720',
#   '1,810,463',
#   '31,072,940',
#   '1,207,359',
#   '628,066',
#   '45,741,007',
#   '1,439,323,776',
#   '6,486,205',
#   '26,545,863',
#   '16,718,965',
#   '540,544',
#   '12,952,218',
#   '625,978',
#   '16,743,927',
#   '5,850,342',
#   '19,129,952',
#   '2,961,167',
#   '89,561,403',
#   '26,378,274',
#   '32,866,272',
#   '27,691,018',
#   '895,312',
#   '1,399,488',
#   '43,849,260',
#   '896,445',
#   '25,499,884',
#   '441,543',
#   '555,987',
#   '298,682',
#   '1,160,164',
#   '4,649,658',
#   '13,132,795',
#   '17,500,658',
#   '586,632',
#   '2,225,734',
#   '400,124',
#   '375,265',
#   '786,552',
#   '280,908',
#   '11,402,528',
#   '272,815',
#   '98,347',
#   '8,947,024',
#   '8,278,724',
#   '23,816,775',
#   '15,893,222',
#   '9,537,645',
#   '393,244',
#   '77,265',
#   '20,250,833',
#   '397,628',
#   '164,093',
#   '20,903,273',
#   '2,142,249',
#   '5,518,087',
#   '106,766',
#   '7,496,981',
#   '988,000',
#   '1,318,445',
#   '11,193,725',
#   '6,624,554',
#   '1,402,985',
#   '341,243',
#   '12,123,200',
#   '2,416,668',
#   '7,275,560',
#   '11,890,784',
#   '4,829,767',
#   '29,825,964',
#   '3,546,421',
#   '7,976,983',
#   '183,627',
#   '24,206,644',
#   '5,057,681',
#   '85,033',
#   '33,931',
#   '33,691',
#   '16,425,864',
#   '1,968,001',
#   '1,271,768',
#   '287,375',
#   '869,601',
#   '38,128',
#   '39,242',
#   '42,876',
#   '4,822,233',
#   '38,666',
#   '62,278',
#   '771,608',
#   '38,717',
#   '30,231',
#   '219,159',
#   '110,940',
#   '26,223',
#   '9,877',
#   '97,929',
#   '59,734,218',
#   '48,863',
#   '65,722',
#   '53,199',
#   '-',
#   '437,479',
#   '71,986',
#   '56,770',
#   '112,523',
#   '285,498',
#   '15,003',
#   '3,480',
#   '649,335',
#   '5,794',
#   '801',
#   '4,992',
#   '686,884',
#   '597,339',
#   '-',
#   '59,190',
#   '307,145',
#   '198,414',
#   '6,077',
#   '115,023']]

# %%
for i in range(9):
    print(len( all_data[i]) )
# Out:
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221
# 221

# %%
import pandas as pd

dict_dat = { "국가":all_data[0], 
             "확진자":all_data[1],
             "위중증":all_data[2],
             "사망자":all_data[3],
             "완치":all_data[4],
             "치명(%)":all_data[5],
             "완치(%)":all_data[6],
             "발생률":all_data[7],
             "인구수":all_data[8]
           }

dat = pd.DataFrame(dict_dat)
dat
# Out:
#            국가                     확진자             위중증                사망자  \
# 0        미국🇺🇸  36,449,535\n(+144,461)  13,081\n(+210)    632,647\n(+748)
# 1        인도🇮🇳   31,902,422\n(+40,647)           8,944    427,565\n(+657)
# 2       브라질🇧🇷   20,108,746\n(+42,159)           8,318  561,807\n(+1,006)
# 3       러시아🇷🇺    6,424,884\n(+22,320)           2,300    164,094\n(+793)
# 4       프랑스🇫🇷    6,258,953\n(+25,077)    1,458\n(+38)     112,158\n(+60)
# ..        ...                     ...             ...                ...
# 216   마셜 제도🇲🇭                       4             N/A                  0
# 217    바누아투🇻🇺                       4             N/A                  1
# 218     사모아🇼🇸                       3             N/A                  0
# 219  세인트헬레나🇸🇭                       2             N/A                  0
# 220  미크로네시아🇫🇲                       1             N/A                  0
#
#                         완치 치명(%) 완치(%)      발생률            인구수
# 0    29,834,481\n(+28,888)   1.7  81.9  110,328    331,002,651
# 1    31,055,861\n(+40,017)   1.3  97.3   23,141  1,380,004,385
# 2    18,868,602\n(+28,370)   2.8  93.8   94,805    212,559,417
# 3     5,739,838\n(+19,485)   2.6  89.3   44,026    145,934,462
# 4     5,743,040\n(+10,889)   1.8  91.8   96,283     65,273,511
# ..                     ...   ...   ...      ...            ...
# 216                      4     -   100       68         59,190
# 217                      3    25    75       13        307,145
# 218                      3     -   100       15        198,414
# 219                      2     -   100      329          6,077
# 220                      1     -   100        9        115,023
#
# [221 rows x 9 columns]

# %% [markdown]
# ### 주어진 데이터를 좀 더 사용하기 쉽게 전처리한다.

# %%
### 확진자를 총 확진자와, 일일 확진자로
dat['확진자_합계'] = dat['확진자'].str.split('\n').str[0]
dat['확진자1일'] = dat['확진자'].str.split('\n').str[1]

dat['사망자합계'] = dat['사망자'].str.split('\n').str[0]
dat['사망자1일'] = dat['사망자'].str.split('\n').str[1]

dat['완치합계'] = dat['완치'].str.split('\n').str[0]
dat['완치1일'] = dat['완치'].str.split('\n').str[1]

dat = dat.drop( [ '확진자', '사망자', '완치'], axis=1)

dat.head()
# Out:
#       국가             위중증 치명(%) 완치(%)      발생률            인구수      확진자_합계  \
# 0   미국🇺🇸  13,081\n(+210)   1.7  81.9  110,328    331,002,651  36,449,535
# 1   인도🇮🇳           8,944   1.3  97.3   23,141  1,380,004,385  31,902,422
# 2  브라질🇧🇷           8,318   2.8  93.8   94,805    212,559,417  20,108,746
# 3  러시아🇷🇺           2,300   2.6  89.3   44,026    145,934,462   6,424,884
# 4  프랑스🇫🇷    1,458\n(+38)   1.8  91.8   96,283     65,273,511   6,258,953
#
#         확진자1일    사망자합계     사망자1일        완치합계       완치1일
# 0  (+144,461)  632,647    (+748)  29,834,481  (+28,888)
# 1   (+40,647)  427,565    (+657)  31,055,861  (+40,017)
# 2   (+42,159)  561,807  (+1,006)  18,868,602  (+28,370)
# 3   (+22,320)  164,094    (+793)   5,739,838  (+19,485)
# 4   (+25,077)  112,158     (+60)   5,743,040  (+10,889)

# %%
dat['위중증'] = dat['위중증'].str.replace(pat=r'[,()]', repl=r'', regex=True)
dat['발생률'] = dat['발생률'].str.replace(pat=r'[,]', repl=r'', regex=True)
dat['인구수'] = dat['인구수'].str.replace(pat=r'[,]', repl=r'', regex=True)

dat['확진자_합계'] = dat['확진자_합계'].str.replace(pat=r'[,]', repl=r'', regex=True)
dat['확진자1일'] = dat['확진자1일'].str.replace(pat=r'[,()]', repl=r'', regex=True)

dat['사망자합계'] = dat['사망자합계'].str.replace(pat=r'[,]', repl=r'', regex=True)
dat['사망자1일'] = dat['사망자1일'].str.replace(pat=r'[,()]', repl=r'', regex=True)

dat['완치합계'] = dat['완치합계'].str.replace(pat=r'[,]', repl=r'', regex=True)
dat['완치1일'] = dat['완치1일'].str.replace(pat=r'[,()]', repl=r'', regex=True)
dat.head()
# Out:
#       국가          위중증 치명(%) 완치(%)     발생률         인구수    확진자_합계    확진자1일  \
# 0   미국🇺🇸  13081\n+210   1.7  81.9  110328   331002651  36449535  +144461
# 1   인도🇮🇳         8944   1.3  97.3   23141  1380004385  31902422   +40647
# 2  브라질🇧🇷         8318   2.8  93.8   94805   212559417  20108746   +42159
# 3  러시아🇷🇺         2300   2.6  89.3   44026   145934462   6424884   +22320
# 4  프랑스🇫🇷    1458\n+38   1.8  91.8   96283    65273511   6258953   +25077
#
#     사망자합계  사망자1일      완치합계    완치1일
# 0  632647   +748  29834481  +28888
# 1  427565   +657  31055861  +40017
# 2  561807  +1006  18868602  +28370
# 3  164094   +793   5739838  +19485
# 4  112158    +60   5743040  +10889

# %%
from datetime import datetime
from datetime import date
import datetime
import os

today = datetime.date.today()
yesterday = today - datetime.timedelta(days=1)

# print(today)
# print(yesterday)
if flag_today == True:
    file_make_time = today
else:
    file_make_time = yesterday

print( file_make_time )

print( os.getcwd() )
path_dir = os.getcwd() + "\\data\\"
path_file = path_dir + str(file_make_time)
print( path_dir,  path_file, sep="\n" )
# Out:
# 2021-08-07
# C:\Users\toto\Documents\Github\corona_analysis
# C:\Users\toto\Documents\Github\corona_analysis\data\
# C:\Users\toto\Documents\Github\corona_analysis\data\2021-08-07

# %%
dat.to_csv(path_file + "_corona.csv", index=False)
dat.to_excel(path_file + "_corona.xlsx", index=False)
os.listdir( path_dir )
# Out:
# ['2021-08-07_corona.csv',
#  '2021-08-07_corona.xlsx',
#  '20210808_16_today_corona.csv',
#  '20210808_16_today_corona.xlsx',
#  '20210808_16_vaccine_bloomberg.csv',
#  '20210808_16_vaccine_bloomberg.xlsx',
#  'country.csv',
#  'country.xlsx']

# %% [markdown]
# ### 추가 과제
#  * 위증증 - 총 합계와 일일 합계 나누기
#  * 확진자/총인구 값 구하기

# %% [markdown]
# * history
#  * 2021.08.08 version 01
# * 출처를 밝히시고 위의 내용에 대해 자유롭게 사용 가능합니다.
